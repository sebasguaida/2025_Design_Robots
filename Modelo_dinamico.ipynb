# %%
import sympy as sp

# Definir variables simbólicas
q = sp.symbols('q1 q2 q3 q4')  # Ángulos de las articulaciones
q_dot = sp.symbols('q1_dot q2_dot q3_dot q4_dot')  # Velocidades angulares
q_ddot = sp.symbols('q1_ddot q2_ddot q3_ddot q4_ddot')  # Aceleraciones angulares

m = sp.symbols('m1 m2 m3 m4')  # Masas de los enlaces
l = sp.symbols('l1 l2 l3 l4')  # Longitudes de los enlaces
lc = sp.symbols('lc1 lc2 lc3 lc4')  # Distancias al centro de masa
I = sp.symbols('I1 I2 I3 I4')  # Momentos de inercia
g = sp.symbols('g')  # Gravedad
tau = sp.symbols('tau1 tau2 tau3 tau4')  # Torque

# Energía cinética
K = 0
v = []
v_dot = []

for i in range(4):
    if i == 0:
        pos = lc[i] * sp.Matrix([sp.cos(q[i]), sp.sin(q[i])])
    else:
        pos = pos + lc[i] * sp.Matrix([sp.cos(sum(q[:i + 1])), sp.sin(sum(q[:i + 1]))])

    v.append(pos)
    # Inicializar acumulador para sum() como una matriz nula
    v_dot_i = sum((sp.diff(pos, q[j]) * q_dot[j] for j in range(i + 1)), sp.zeros(2, 1))
    v_dot.append(v_dot_i)
    K += 0.5 * m[i] * (v_dot_i.T * v_dot_i)[0] + 0.5 * I[i] * (sum(q_dot[:i + 1])**2)

# Energía potencial
P = 0
for i in range(4):
    P += m[i] * g * (sum(l[:i]) + lc[i]) * sp.sin(sum(q[:i + 1]))

# Lagrangiano
L = K - P

# Ecuaciones de Lagrange
equations = []
for i in range(4):
    dL_dq = sp.diff(L, q[i])
    dL_dqdot = sp.diff(L, q_dot[i])
    dL_dqdot_dt = sum((sp.diff(dL_dqdot, q[j]) * q_dot[j] for j in range(4))) + sp.diff(dL_dqdot, q_dot[i]) * q_ddot[i]
    eq = dL_dqdot_dt - dL_dq - tau[i]
    equations.append(eq)  # No simplificar aquí

# Mostrar ecuaciones (sin simplificación inicial)
for i, eq in enumerate(equations):
    print(f"Ecuación {i+1}:")
    sp.pprint(eq)
    print()

# Simplificar ecuaciones al final (si es necesario)
simplified_equations = [sp.simplify(eq) for eq in equations]

# Mostrar ecuaciones simplificadas
print("\nEcuaciones simplificadas:")
for i, eq in enumerate(simplified_equations):
    print(f"Ecuación {i+1}:")
    sp.pprint(eq)
    print()
# Out:
# Ecuación 1:
#                                                                                                    ↪
# g⋅lc₁⋅m₁⋅cos(q₁) + g⋅m₂⋅(l₁ + lc₂)⋅cos(q₁ + q₂) + g⋅m₃⋅(l₁ + l₂ + lc₃)⋅cos(q₁ + q₂ + q₃) + g⋅m₄⋅(l ↪
#
# ↪                                                                                                  ↪
# ↪ ₁ + l₂ + l₃ + lc₄)⋅cos(q₁ + q₂ + q₃ + q₄) - 0.5⋅m₂⋅((-2⋅lc₂⋅q_2_dot⋅sin(q₁ + q₂) + 2⋅q_1_dot⋅(-l ↪
#
# ↪                                                                                                  ↪
# ↪ c₁⋅sin(q₁) - lc₂⋅sin(q₁ + q₂)))⋅(lc₂⋅q_2_dot⋅cos(q₁ + q₂) + q_1_dot⋅(lc₁⋅cos(q₁) + lc₂⋅cos(q₁ +  ↪
#
# ↪                                                                                                  ↪
# ↪ q₂))) + (-lc₂⋅q_2_dot⋅sin(q₁ + q₂) + q_1_dot⋅(-lc₁⋅sin(q₁) - lc₂⋅sin(q₁ + q₂)))⋅(-2⋅lc₂⋅q_2_dot⋅ ↪
#
# ↪                                                                                                  ↪
# ↪ cos(q₁ + q₂) + 2⋅q_1_dot⋅(-lc₁⋅cos(q₁) - lc₂⋅cos(q₁ + q₂)))) - 0.5⋅m₃⋅((-2⋅lc₃⋅q_3_dot⋅sin(q₁ +  ↪
#
# ↪                                                                                                  ↪
# ↪ q₂ + q₃) + 2⋅q_1_dot⋅(-lc₁⋅sin(q₁) - lc₂⋅sin(q₁ + q₂) - lc₃⋅sin(q₁ + q₂ + q₃)) + 2⋅q_2_dot⋅(-lc₂ ↪
#
# ↪                                                                                                  ↪
# ↪ ⋅sin(q₁ + q₂) - lc₃⋅sin(q₁ + q₂ + q₃)))⋅(lc₃⋅q_3_dot⋅cos(q₁ + q₂ + q₃) + q_1_dot⋅(lc₁⋅cos(q₁) +  ↪
#
# ↪                                                                                                  ↪
# ↪ lc₂⋅cos(q₁ + q₂) + lc₃⋅cos(q₁ + q₂ + q₃)) + q_2_dot⋅(lc₂⋅cos(q₁ + q₂) + lc₃⋅cos(q₁ + q₂ + q₃)))  ↪
#
# ↪                                                                                                  ↪
# ↪ + (-lc₃⋅q_3_dot⋅sin(q₁ + q₂ + q₃) + q_1_dot⋅(-lc₁⋅sin(q₁) - lc₂⋅sin(q₁ + q₂) - lc₃⋅sin(q₁ + q₂ + ↪
#
# ↪                                                                                                  ↪
# ↪  q₃)) + q_2_dot⋅(-lc₂⋅sin(q₁ + q₂) - lc₃⋅sin(q₁ + q₂ + q₃)))⋅(-2⋅lc₃⋅q_3_dot⋅cos(q₁ + q₂ + q₃) + ↪
#
# ↪                                                                                                  ↪
# ↪  2⋅q_1_dot⋅(-lc₁⋅cos(q₁) - lc₂⋅cos(q₁ + q₂) - lc₃⋅cos(q₁ + q₂ + q₃)) + 2⋅q_2_dot⋅(-lc₂⋅cos(q₁ +  ↪
#
# ↪                                                                                                  ↪
# ↪ q₂) - lc₃⋅cos(q₁ + q₂ + q₃)))) + 0.5⋅m₄⋅q_4_dot⋅(-2⋅lc₄⋅(-lc₄⋅q_4_dot⋅sin(q₁ + q₂ + q₃ + q₄) + q ↪
#
# ↪                                                                                                  ↪
# ↪ _1_dot⋅(-lc₁⋅sin(q₁) - lc₂⋅sin(q₁ + q₂) - lc₃⋅sin(q₁ + q₂ + q₃) - lc₄⋅sin(q₁ + q₂ + q₃ + q₄)) +  ↪
#
# ↪                                                                                                  ↪
# ↪ q_2_dot⋅(-lc₂⋅sin(q₁ + q₂) - lc₃⋅sin(q₁ + q₂ + q₃) - lc₄⋅sin(q₁ + q₂ + q₃ + q₄)) + q_3_dot⋅(-lc₃ ↪
#
# ↪                                                                                                  ↪
# ↪ ⋅sin(q₁ + q₂ + q₃) - lc₄⋅sin(q₁ + q₂ + q₃ + q₄)))⋅cos(q₁ + q₂ + q₃ + q₄) - 2⋅lc₄⋅(lc₄⋅q_4_dot⋅co ↪
#
# ↪                                                                                                  ↪
# ↪ s(q₁ + q₂ + q₃ + q₄) + q_1_dot⋅(lc₁⋅cos(q₁) + lc₂⋅cos(q₁ + q₂) + lc₃⋅cos(q₁ + q₂ + q₃) + lc₄⋅cos ↪
#
# ↪                                                                                                  ↪
# ↪ (q₁ + q₂ + q₃ + q₄)) + q_2_dot⋅(lc₂⋅cos(q₁ + q₂) + lc₃⋅cos(q₁ + q₂ + q₃) + lc₄⋅cos(q₁ + q₂ + q₃  ↪
#
# ↪                                                                                                  ↪
# ↪ + q₄)) + q_3_dot⋅(lc₃⋅cos(q₁ + q₂ + q₃) + lc₄⋅cos(q₁ + q₂ + q₃ + q₄)))⋅sin(q₁ + q₂ + q₃ + q₄) +  ↪
#
# ↪                                                                                                  ↪
# ↪ (-2⋅lc₁⋅sin(q₁) - 2⋅lc₂⋅sin(q₁ + q₂) - 2⋅lc₃⋅sin(q₁ + q₂ + q₃) - 2⋅lc₄⋅sin(q₁ + q₂ + q₃ + q₄))⋅( ↪
#
# ↪                                                                                                  ↪
# ↪ -lc₄⋅q_1_dot⋅cos(q₁ + q₂ + q₃ + q₄) - lc₄⋅q_2_dot⋅cos(q₁ + q₂ + q₃ + q₄) - lc₄⋅q_3_dot⋅cos(q₁ +  ↪
#
# ↪                                                                                                  ↪
# ↪ q₂ + q₃ + q₄) - lc₄⋅q_4_dot⋅cos(q₁ + q₂ + q₃ + q₄)) + (2⋅lc₁⋅cos(q₁) + 2⋅lc₂⋅cos(q₁ + q₂) + 2⋅lc ↪
#
# ↪                                                                                                  ↪
# ↪ ₃⋅cos(q₁ + q₂ + q₃) + 2⋅lc₄⋅cos(q₁ + q₂ + q₃ + q₄))⋅(-lc₄⋅q_1_dot⋅sin(q₁ + q₂ + q₃ + q₄) - lc₄⋅q ↪
#
# ↪                                                                                                  ↪
# ↪ _2_dot⋅sin(q₁ + q₂ + q₃ + q₄) - lc₄⋅q_3_dot⋅sin(q₁ + q₂ + q₃ + q₄) - lc₄⋅q_4_dot⋅sin(q₁ + q₂ + q ↪
#
# ↪                                                                                                  ↪
# ↪ ₃ + q₄))) - 0.5⋅m₄⋅((-2⋅lc₄⋅q_4_dot⋅sin(q₁ + q₂ + q₃ + q₄) + 2⋅q_1_dot⋅(-lc₁⋅sin(q₁) - lc₂⋅sin(q ↪
#
# ↪                                                                                                  ↪
# ↪ ₁ + q₂) - lc₃⋅sin(q₁ + q₂ + q₃) - lc₄⋅sin(q₁ + q₂ + q₃ + q₄)) + 2⋅q_2_dot⋅(-lc₂⋅sin(q₁ + q₂) - l ↪
#
# ↪                                                                                                  ↪
# ↪ c₃⋅sin(q₁ + q₂ + q₃) - lc₄⋅sin(q₁ + q₂ + q₃ + q₄)) + 2⋅q_3_dot⋅(-lc₃⋅sin(q₁ + q₂ + q₃) - lc₄⋅sin ↪
#
# ↪                                                                                                  ↪
# ↪ (q₁ + q₂ + q₃ + q₄)))⋅(lc₄⋅q_4_dot⋅cos(q₁ + q₂ + q₃ + q₄) + q_1_dot⋅(lc₁⋅cos(q₁) + lc₂⋅cos(q₁ +  ↪
#
# ↪                                                                                                  ↪
# ↪ q₂) + lc₃⋅cos(q₁ + q₂ + q₃) + lc₄⋅cos(q₁ + q₂ + q₃ + q₄)) + q_2_dot⋅(lc₂⋅cos(q₁ + q₂) + lc₃⋅cos( ↪
#
# ↪                                                                                                  ↪
# ↪ q₁ + q₂ + q₃) + lc₄⋅cos(q₁ + q₂ + q₃ + q₄)) + q_3_dot⋅(lc₃⋅cos(q₁ + q₂ + q₃) + lc₄⋅cos(q₁ + q₂ + ↪
#
# ↪                                                                                                  ↪
# ↪  q₃ + q₄))) + (-lc₄⋅q_4_dot⋅sin(q₁ + q₂ + q₃ + q₄) + q_1_dot⋅(-lc₁⋅sin(q₁) - lc₂⋅sin(q₁ + q₂) -  ↪
#
# ↪                                                                                                  ↪
# ↪ lc₃⋅sin(q₁ + q₂ + q₃) - lc₄⋅sin(q₁ + q₂ + q₃ + q₄)) + q_2_dot⋅(-lc₂⋅sin(q₁ + q₂) - lc₃⋅sin(q₁ +  ↪
#
# ↪                                                                                                  ↪
# ↪ q₂ + q₃) - lc₄⋅sin(q₁ + q₂ + q₃ + q₄)) + q_3_dot⋅(-lc₃⋅sin(q₁ + q₂ + q₃) - lc₄⋅sin(q₁ + q₂ + q₃  ↪
#
# ↪                                                                                                  ↪
# ↪ + q₄)))⋅(-2⋅lc₄⋅q_4_dot⋅cos(q₁ + q₂ + q₃ + q₄) + 2⋅q_1_dot⋅(-lc₁⋅cos(q₁) - lc₂⋅cos(q₁ + q₂) - lc ↪
#
# ↪                                                                                                  ↪
# ↪ ₃⋅cos(q₁ + q₂ + q₃) - lc₄⋅cos(q₁ + q₂ + q₃ + q₄)) + 2⋅q_2_dot⋅(-lc₂⋅cos(q₁ + q₂) - lc₃⋅cos(q₁ +  ↪
#
# ↪                                                                                                  ↪
# ↪ q₂ + q₃) - lc₄⋅cos(q₁ + q₂ + q₃ + q₄)) + 2⋅q_3_dot⋅(-lc₃⋅cos(q₁ + q₂ + q₃) - lc₄⋅cos(q₁ + q₂ + q ↪
#
# ↪                    ⎛                                           ⎛     2    2            2    2    ↪
# ↪ ₃ + q₄)))) + q_1_ḋ⋅⎝1.0⋅I₁ + 1.0⋅I₂ + 1.0⋅I₃ + 1.0⋅I₄ + 0.5⋅m₁⋅⎝2⋅lc₁ ⋅sin (q₁) + 2⋅lc₁ ⋅cos (q₁ ↪
#
# ↪  ⎞                                                                                               ↪
# ↪ )⎠ + 0.5⋅m₂⋅((-2⋅lc₁⋅sin(q₁) - 2⋅lc₂⋅sin(q₁ + q₂))⋅(-lc₁⋅sin(q₁) - lc₂⋅sin(q₁ + q₂)) + (lc₁⋅cos( ↪
#
# ↪                                                                                                  ↪
# ↪ q₁) + lc₂⋅cos(q₁ + q₂))⋅(2⋅lc₁⋅cos(q₁) + 2⋅lc₂⋅cos(q₁ + q₂))) + 0.5⋅m₃⋅((-2⋅lc₁⋅sin(q₁) - 2⋅lc₂⋅ ↪
#
# ↪                                                                                                  ↪
# ↪ sin(q₁ + q₂) - 2⋅lc₃⋅sin(q₁ + q₂ + q₃))⋅(-lc₁⋅sin(q₁) - lc₂⋅sin(q₁ + q₂) - lc₃⋅sin(q₁ + q₂ + q₃) ↪
#
# ↪                                                                                                  ↪
# ↪ ) + (lc₁⋅cos(q₁) + lc₂⋅cos(q₁ + q₂) + lc₃⋅cos(q₁ + q₂ + q₃))⋅(2⋅lc₁⋅cos(q₁) + 2⋅lc₂⋅cos(q₁ + q₂) ↪
#
# ↪                                                                                                  ↪
# ↪  + 2⋅lc₃⋅cos(q₁ + q₂ + q₃))) + 0.5⋅m₄⋅((-2⋅lc₁⋅sin(q₁) - 2⋅lc₂⋅sin(q₁ + q₂) - 2⋅lc₃⋅sin(q₁ + q₂  ↪
#
# ↪                                                                                                  ↪
# ↪ + q₃) - 2⋅lc₄⋅sin(q₁ + q₂ + q₃ + q₄))⋅(-lc₁⋅sin(q₁) - lc₂⋅sin(q₁ + q₂) - lc₃⋅sin(q₁ + q₂ + q₃) - ↪
#
# ↪                                                                                                  ↪
# ↪  lc₄⋅sin(q₁ + q₂ + q₃ + q₄)) + (lc₁⋅cos(q₁) + lc₂⋅cos(q₁ + q₂) + lc₃⋅cos(q₁ + q₂ + q₃) + lc₄⋅cos ↪
#
# ↪                                                                                                  ↪
# ↪ (q₁ + q₂ + q₃ + q₄))⋅(2⋅lc₁⋅cos(q₁) + 2⋅lc₂⋅cos(q₁ + q₂) + 2⋅lc₃⋅cos(q₁ + q₂ + q₃) + 2⋅lc₄⋅cos(q ↪
#
# ↪                    ⎞                                                                             ↪
# ↪ ₁ + q₂ + q₃ + q₄)))⎠ + q_1_dot⋅(0.5⋅m₂⋅((-2⋅lc₁⋅sin(q₁) - 2⋅lc₂⋅sin(q₁ + q₂))⋅(-lc₂⋅q_2_dot⋅cos( ↪
#
# ↪                                                                                                  ↪
# ↪ q₁ + q₂) + q_1_dot⋅(-lc₁⋅cos(q₁) - lc₂⋅cos(q₁ + q₂))) + (-2⋅lc₁⋅sin(q₁) - 2⋅lc₂⋅sin(q₁ + q₂))⋅(l ↪
#
# ↪                                                                                                  ↪
# ↪ c₂⋅q_2_dot⋅cos(q₁ + q₂) + q_1_dot⋅(lc₁⋅cos(q₁) + lc₂⋅cos(q₁ + q₂))) + (-2⋅lc₁⋅cos(q₁) - 2⋅lc₂⋅co ↪
#
# ↪                                                                                                  ↪
# ↪ s(q₁ + q₂))⋅(-lc₂⋅q_2_dot⋅sin(q₁ + q₂) + q_1_dot⋅(-lc₁⋅sin(q₁) - lc₂⋅sin(q₁ + q₂))) + (2⋅lc₁⋅cos ↪
#
# ↪                                                                                                  ↪
# ↪ (q₁) + 2⋅lc₂⋅cos(q₁ + q₂))⋅(-lc₂⋅q_2_dot⋅sin(q₁ + q₂) + q_1_dot⋅(-lc₁⋅sin(q₁) - lc₂⋅sin(q₁ + q₂) ↪
#
# ↪                                                                                                  ↪
# ↪ ))) + 0.5⋅m₃⋅((-2⋅lc₁⋅sin(q₁) - 2⋅lc₂⋅sin(q₁ + q₂) - 2⋅lc₃⋅sin(q₁ + q₂ + q₃))⋅(-lc₃⋅q_3_dot⋅cos( ↪
#
# ↪                                                                                                  ↪
# ↪ q₁ + q₂ + q₃) + q_1_dot⋅(-lc₁⋅cos(q₁) - lc₂⋅cos(q₁ + q₂) - lc₃⋅cos(q₁ + q₂ + q₃)) + q_2_dot⋅(-lc ↪
#
# ↪                                                                                                  ↪
# ↪ ₂⋅cos(q₁ + q₂) - lc₃⋅cos(q₁ + q₂ + q₃))) + (-2⋅lc₁⋅sin(q₁) - 2⋅lc₂⋅sin(q₁ + q₂) - 2⋅lc₃⋅sin(q₁ + ↪
#
# ↪                                                                                                  ↪
# ↪  q₂ + q₃))⋅(lc₃⋅q_3_dot⋅cos(q₁ + q₂ + q₃) + q_1_dot⋅(lc₁⋅cos(q₁) + lc₂⋅cos(q₁ + q₂) + lc₃⋅cos(q₁ ↪
#
# ↪                                                                                                  ↪
# ↪  + q₂ + q₃)) + q_2_dot⋅(lc₂⋅cos(q₁ + q₂) + lc₃⋅cos(q₁ + q₂ + q₃))) + (-2⋅lc₁⋅cos(q₁) - 2⋅lc₂⋅cos ↪
#
# ↪                                                                                                  ↪
# ↪ (q₁ + q₂) - 2⋅lc₃⋅cos(q₁ + q₂ + q₃))⋅(-lc₃⋅q_3_dot⋅sin(q₁ + q₂ + q₃) + q_1_dot⋅(-lc₁⋅sin(q₁) - l ↪
#
# ↪                                                                                                  ↪
# ↪ c₂⋅sin(q₁ + q₂) - lc₃⋅sin(q₁ + q₂ + q₃)) + q_2_dot⋅(-lc₂⋅sin(q₁ + q₂) - lc₃⋅sin(q₁ + q₂ + q₃)))  ↪
#
# ↪                                                                                                  ↪
# ↪ + (2⋅lc₁⋅cos(q₁) + 2⋅lc₂⋅cos(q₁ + q₂) + 2⋅lc₃⋅cos(q₁ + q₂ + q₃))⋅(-lc₃⋅q_3_dot⋅sin(q₁ + q₂ + q₃) ↪
#
# ↪                                                                                                  ↪
# ↪  + q_1_dot⋅(-lc₁⋅sin(q₁) - lc₂⋅sin(q₁ + q₂) - lc₃⋅sin(q₁ + q₂ + q₃)) + q_2_dot⋅(-lc₂⋅sin(q₁ + q₂ ↪
#
# ↪                                                                                                  ↪
# ↪ ) - lc₃⋅sin(q₁ + q₂ + q₃)))) + 0.5⋅m₄⋅((-2⋅lc₁⋅sin(q₁) - 2⋅lc₂⋅sin(q₁ + q₂) - 2⋅lc₃⋅sin(q₁ + q₂  ↪
#
# ↪                                                                                                  ↪
# ↪ + q₃) - 2⋅lc₄⋅sin(q₁ + q₂ + q₃ + q₄))⋅(-lc₄⋅q_4_dot⋅cos(q₁ + q₂ + q₃ + q₄) + q_1_dot⋅(-lc₁⋅cos(q ↪
#
# ↪                                                                                                  ↪
# ↪ ₁) - lc₂⋅cos(q₁ + q₂) - lc₃⋅cos(q₁ + q₂ + q₃) - lc₄⋅cos(q₁ + q₂ + q₃ + q₄)) + q_2_dot⋅(-lc₂⋅cos( ↪
#
# ↪                                                                                                  ↪
# ↪ q₁ + q₂) - lc₃⋅cos(q₁ + q₂ + q₃) - lc₄⋅cos(q₁ + q₂ + q₃ + q₄)) + q_3_dot⋅(-lc₃⋅cos(q₁ + q₂ + q₃) ↪
#
# ↪                                                                                                  ↪
# ↪  - lc₄⋅cos(q₁ + q₂ + q₃ + q₄))) + (-2⋅lc₁⋅sin(q₁) - 2⋅lc₂⋅sin(q₁ + q₂) - 2⋅lc₃⋅sin(q₁ + q₂ + q₃) ↪
#
# ↪                                                                                                  ↪
# ↪  - 2⋅lc₄⋅sin(q₁ + q₂ + q₃ + q₄))⋅(lc₄⋅q_4_dot⋅cos(q₁ + q₂ + q₃ + q₄) + q_1_dot⋅(lc₁⋅cos(q₁) + lc ↪
#
# ↪                                                                                                  ↪
# ↪ ₂⋅cos(q₁ + q₂) + lc₃⋅cos(q₁ + q₂ + q₃) + lc₄⋅cos(q₁ + q₂ + q₃ + q₄)) + q_2_dot⋅(lc₂⋅cos(q₁ + q₂) ↪
#
# ↪                                                                                                  ↪
# ↪  + lc₃⋅cos(q₁ + q₂ + q₃) + lc₄⋅cos(q₁ + q₂ + q₃ + q₄)) + q_3_dot⋅(lc₃⋅cos(q₁ + q₂ + q₃) + lc₄⋅co ↪
#
# ↪                                                                                                  ↪
# ↪ s(q₁ + q₂ + q₃ + q₄))) + (-2⋅lc₁⋅cos(q₁) - 2⋅lc₂⋅cos(q₁ + q₂) - 2⋅lc₃⋅cos(q₁ + q₂ + q₃) - 2⋅lc₄⋅ ↪
#
# ↪                                                                                                  ↪
# ↪ cos(q₁ + q₂ + q₃ + q₄))⋅(-lc₄⋅q_4_dot⋅sin(q₁ + q₂ + q₃ + q₄) + q_1_dot⋅(-lc₁⋅sin(q₁) - lc₂⋅sin(q ↪
#
# ↪                                                                                                  ↪
# ↪ ₁ + q₂) - lc₃⋅sin(q₁ + q₂ + q₃) - lc₄⋅sin(q₁ + q₂ + q₃ + q₄)) + q_2_dot⋅(-lc₂⋅sin(q₁ + q₂) - lc₃ ↪
#
# ↪                                                                                                  ↪
# ↪ ⋅sin(q₁ + q₂ + q₃) - lc₄⋅sin(q₁ + q₂ + q₃ + q₄)) + q_3_dot⋅(-lc₃⋅sin(q₁ + q₂ + q₃) - lc₄⋅sin(q₁  ↪
#
# ↪                                                                                                  ↪
# ↪ + q₂ + q₃ + q₄))) + (2⋅lc₁⋅cos(q₁) + 2⋅lc₂⋅cos(q₁ + q₂) + 2⋅lc₃⋅cos(q₁ + q₂ + q₃) + 2⋅lc₄⋅cos(q₁ ↪
#
# ↪                                                                                                  ↪
# ↪  + q₂ + q₃ + q₄))⋅(-lc₄⋅q_4_dot⋅sin(q₁ + q₂ + q₃ + q₄) + q_1_dot⋅(-lc₁⋅sin(q₁) - lc₂⋅sin(q₁ + q₂ ↪
#
# ↪                                                                                                  ↪
# ↪ ) - lc₃⋅sin(q₁ + q₂ + q₃) - lc₄⋅sin(q₁ + q₂ + q₃ + q₄)) + q_2_dot⋅(-lc₂⋅sin(q₁ + q₂) - lc₃⋅sin(q ↪
#
# ↪                                                                                                  ↪
# ↪ ₁ + q₂ + q₃) - lc₄⋅sin(q₁ + q₂ + q₃ + q₄)) + q_3_dot⋅(-lc₃⋅sin(q₁ + q₂ + q₃) - lc₄⋅sin(q₁ + q₂ + ↪
#
# ↪                                                                                                  ↪
# ↪  q₃ + q₄))))) + q_2_dot⋅(0.5⋅m₂⋅(-2⋅lc₂⋅(-lc₂⋅q_2_dot⋅sin(q₁ + q₂) + q_1_dot⋅(-lc₁⋅sin(q₁) - lc₂ ↪
#
# ↪                                                                                                  ↪
# ↪ ⋅sin(q₁ + q₂)))⋅cos(q₁ + q₂) - 2⋅lc₂⋅(lc₂⋅q_2_dot⋅cos(q₁ + q₂) + q_1_dot⋅(lc₁⋅cos(q₁) + lc₂⋅cos( ↪
#
# ↪                                                                                                  ↪
# ↪ q₁ + q₂)))⋅sin(q₁ + q₂) + (-2⋅lc₁⋅sin(q₁) - 2⋅lc₂⋅sin(q₁ + q₂))⋅(-lc₂⋅q_1_dot⋅cos(q₁ + q₂) - lc₂ ↪
#
# ↪                                                                                                  ↪
# ↪ ⋅q_2_dot⋅cos(q₁ + q₂)) + (2⋅lc₁⋅cos(q₁) + 2⋅lc₂⋅cos(q₁ + q₂))⋅(-lc₂⋅q_1_dot⋅sin(q₁ + q₂) - lc₂⋅q ↪
#
# ↪                                                                                                  ↪
# ↪ _2_dot⋅sin(q₁ + q₂))) + 0.5⋅m₃⋅((-2⋅lc₂⋅sin(q₁ + q₂) - 2⋅lc₃⋅sin(q₁ + q₂ + q₃))⋅(lc₃⋅q_3_dot⋅cos ↪
#
# ↪                                                                                                  ↪
# ↪ (q₁ + q₂ + q₃) + q_1_dot⋅(lc₁⋅cos(q₁) + lc₂⋅cos(q₁ + q₂) + lc₃⋅cos(q₁ + q₂ + q₃)) + q_2_dot⋅(lc₂ ↪
#
# ↪                                                                                                  ↪
# ↪ ⋅cos(q₁ + q₂) + lc₃⋅cos(q₁ + q₂ + q₃))) + (-2⋅lc₂⋅cos(q₁ + q₂) - 2⋅lc₃⋅cos(q₁ + q₂ + q₃))⋅(-lc₃⋅ ↪
#
# ↪                                                                                                  ↪
# ↪ q_3_dot⋅sin(q₁ + q₂ + q₃) + q_1_dot⋅(-lc₁⋅sin(q₁) - lc₂⋅sin(q₁ + q₂) - lc₃⋅sin(q₁ + q₂ + q₃)) +  ↪
#
# ↪                                                                                                  ↪
# ↪ q_2_dot⋅(-lc₂⋅sin(q₁ + q₂) - lc₃⋅sin(q₁ + q₂ + q₃))) + (-2⋅lc₁⋅sin(q₁) - 2⋅lc₂⋅sin(q₁ + q₂) - 2⋅ ↪
#
# ↪                                                                                                  ↪
# ↪ lc₃⋅sin(q₁ + q₂ + q₃))⋅(-lc₃⋅q_3_dot⋅cos(q₁ + q₂ + q₃) + q_1_dot⋅(-lc₂⋅cos(q₁ + q₂) - lc₃⋅cos(q₁ ↪
#
# ↪                                                                                                  ↪
# ↪  + q₂ + q₃)) + q_2_dot⋅(-lc₂⋅cos(q₁ + q₂) - lc₃⋅cos(q₁ + q₂ + q₃))) + (2⋅lc₁⋅cos(q₁) + 2⋅lc₂⋅cos ↪
#
# ↪                                                                                                  ↪
# ↪ (q₁ + q₂) + 2⋅lc₃⋅cos(q₁ + q₂ + q₃))⋅(-lc₃⋅q_3_dot⋅sin(q₁ + q₂ + q₃) + q_1_dot⋅(-lc₂⋅sin(q₁ + q₂ ↪
#
# ↪                                                                                                  ↪
# ↪ ) - lc₃⋅sin(q₁ + q₂ + q₃)) + q_2_dot⋅(-lc₂⋅sin(q₁ + q₂) - lc₃⋅sin(q₁ + q₂ + q₃)))) + 0.5⋅m₄⋅((-2 ↪
#
# ↪                                                                                                  ↪
# ↪ ⋅lc₂⋅sin(q₁ + q₂) - 2⋅lc₃⋅sin(q₁ + q₂ + q₃) - 2⋅lc₄⋅sin(q₁ + q₂ + q₃ + q₄))⋅(lc₄⋅q_4_dot⋅cos(q₁  ↪
#
# ↪                                                                                                  ↪
# ↪ + q₂ + q₃ + q₄) + q_1_dot⋅(lc₁⋅cos(q₁) + lc₂⋅cos(q₁ + q₂) + lc₃⋅cos(q₁ + q₂ + q₃) + lc₄⋅cos(q₁ + ↪
#
# ↪                                                                                                  ↪
# ↪  q₂ + q₃ + q₄)) + q_2_dot⋅(lc₂⋅cos(q₁ + q₂) + lc₃⋅cos(q₁ + q₂ + q₃) + lc₄⋅cos(q₁ + q₂ + q₃ + q₄) ↪
#
# ↪                                                                                                  ↪
# ↪ ) + q_3_dot⋅(lc₃⋅cos(q₁ + q₂ + q₃) + lc₄⋅cos(q₁ + q₂ + q₃ + q₄))) + (-2⋅lc₂⋅cos(q₁ + q₂) - 2⋅lc₃ ↪
#
# ↪                                                                                                  ↪
# ↪ ⋅cos(q₁ + q₂ + q₃) - 2⋅lc₄⋅cos(q₁ + q₂ + q₃ + q₄))⋅(-lc₄⋅q_4_dot⋅sin(q₁ + q₂ + q₃ + q₄) + q_1_do ↪
#
# ↪                                                                                                  ↪
# ↪ t⋅(-lc₁⋅sin(q₁) - lc₂⋅sin(q₁ + q₂) - lc₃⋅sin(q₁ + q₂ + q₃) - lc₄⋅sin(q₁ + q₂ + q₃ + q₄)) + q_2_d ↪
#
# ↪                                                                                                  ↪
# ↪ ot⋅(-lc₂⋅sin(q₁ + q₂) - lc₃⋅sin(q₁ + q₂ + q₃) - lc₄⋅sin(q₁ + q₂ + q₃ + q₄)) + q_3_dot⋅(-lc₃⋅sin( ↪
#
# ↪                                                                                                  ↪
# ↪ q₁ + q₂ + q₃) - lc₄⋅sin(q₁ + q₂ + q₃ + q₄))) + (-2⋅lc₁⋅sin(q₁) - 2⋅lc₂⋅sin(q₁ + q₂) - 2⋅lc₃⋅sin( ↪
#
# ↪                                                                                                  ↪
# ↪ q₁ + q₂ + q₃) - 2⋅lc₄⋅sin(q₁ + q₂ + q₃ + q₄))⋅(-lc₄⋅q_4_dot⋅cos(q₁ + q₂ + q₃ + q₄) + q_1_dot⋅(-l ↪
#
# ↪                                                                                                  ↪
# ↪ c₂⋅cos(q₁ + q₂) - lc₃⋅cos(q₁ + q₂ + q₃) - lc₄⋅cos(q₁ + q₂ + q₃ + q₄)) + q_2_dot⋅(-lc₂⋅cos(q₁ + q ↪
#
# ↪                                                                                                  ↪
# ↪ ₂) - lc₃⋅cos(q₁ + q₂ + q₃) - lc₄⋅cos(q₁ + q₂ + q₃ + q₄)) + q_3_dot⋅(-lc₃⋅cos(q₁ + q₂ + q₃) - lc₄ ↪
#
# ↪                                                                                                  ↪
# ↪ ⋅cos(q₁ + q₂ + q₃ + q₄))) + (2⋅lc₁⋅cos(q₁) + 2⋅lc₂⋅cos(q₁ + q₂) + 2⋅lc₃⋅cos(q₁ + q₂ + q₃) + 2⋅lc ↪
#
# ↪                                                                                                  ↪
# ↪ ₄⋅cos(q₁ + q₂ + q₃ + q₄))⋅(-lc₄⋅q_4_dot⋅sin(q₁ + q₂ + q₃ + q₄) + q_1_dot⋅(-lc₂⋅sin(q₁ + q₂) - lc ↪
#
# ↪                                                                                                  ↪
# ↪ ₃⋅sin(q₁ + q₂ + q₃) - lc₄⋅sin(q₁ + q₂ + q₃ + q₄)) + q_2_dot⋅(-lc₂⋅sin(q₁ + q₂) - lc₃⋅sin(q₁ + q₂ ↪
#
# ↪                                                                                                  ↪
# ↪  + q₃) - lc₄⋅sin(q₁ + q₂ + q₃ + q₄)) + q_3_dot⋅(-lc₃⋅sin(q₁ + q₂ + q₃) - lc₄⋅sin(q₁ + q₂ + q₃ +  ↪
#
# ↪                                                                                                  ↪
# ↪ q₄))))) + q_3_dot⋅(0.5⋅m₃⋅(-2⋅lc₃⋅(-lc₃⋅q_3_dot⋅sin(q₁ + q₂ + q₃) + q_1_dot⋅(-lc₁⋅sin(q₁) - lc₂⋅ ↪
#
# ↪                                                                                                  ↪
# ↪ sin(q₁ + q₂) - lc₃⋅sin(q₁ + q₂ + q₃)) + q_2_dot⋅(-lc₂⋅sin(q₁ + q₂) - lc₃⋅sin(q₁ + q₂ + q₃)))⋅cos ↪
#
# ↪                                                                                                  ↪
# ↪ (q₁ + q₂ + q₃) - 2⋅lc₃⋅(lc₃⋅q_3_dot⋅cos(q₁ + q₂ + q₃) + q_1_dot⋅(lc₁⋅cos(q₁) + lc₂⋅cos(q₁ + q₂)  ↪
#
# ↪                                                                                                  ↪
# ↪ + lc₃⋅cos(q₁ + q₂ + q₃)) + q_2_dot⋅(lc₂⋅cos(q₁ + q₂) + lc₃⋅cos(q₁ + q₂ + q₃)))⋅sin(q₁ + q₂ + q₃) ↪
#
# ↪                                                                                                  ↪
# ↪  + (-2⋅lc₁⋅sin(q₁) - 2⋅lc₂⋅sin(q₁ + q₂) - 2⋅lc₃⋅sin(q₁ + q₂ + q₃))⋅(-lc₃⋅q_1_dot⋅cos(q₁ + q₂ + q ↪
#
# ↪                                                                                                  ↪
# ↪ ₃) - lc₃⋅q_2_dot⋅cos(q₁ + q₂ + q₃) - lc₃⋅q_3_dot⋅cos(q₁ + q₂ + q₃)) + (2⋅lc₁⋅cos(q₁) + 2⋅lc₂⋅cos ↪
#
# ↪                                                                                                  ↪
# ↪ (q₁ + q₂) + 2⋅lc₃⋅cos(q₁ + q₂ + q₃))⋅(-lc₃⋅q_1_dot⋅sin(q₁ + q₂ + q₃) - lc₃⋅q_2_dot⋅sin(q₁ + q₂ + ↪
#
# ↪                                                                                                  ↪
# ↪  q₃) - lc₃⋅q_3_dot⋅sin(q₁ + q₂ + q₃))) + 0.5⋅m₄⋅((-2⋅lc₃⋅sin(q₁ + q₂ + q₃) - 2⋅lc₄⋅sin(q₁ + q₂ + ↪
#
# ↪                                                                                                  ↪
# ↪  q₃ + q₄))⋅(lc₄⋅q_4_dot⋅cos(q₁ + q₂ + q₃ + q₄) + q_1_dot⋅(lc₁⋅cos(q₁) + lc₂⋅cos(q₁ + q₂) + lc₃⋅c ↪
#
# ↪                                                                                                  ↪
# ↪ os(q₁ + q₂ + q₃) + lc₄⋅cos(q₁ + q₂ + q₃ + q₄)) + q_2_dot⋅(lc₂⋅cos(q₁ + q₂) + lc₃⋅cos(q₁ + q₂ + q ↪
#
# ↪                                                                                                  ↪
# ↪ ₃) + lc₄⋅cos(q₁ + q₂ + q₃ + q₄)) + q_3_dot⋅(lc₃⋅cos(q₁ + q₂ + q₃) + lc₄⋅cos(q₁ + q₂ + q₃ + q₄))) ↪
#
# ↪                                                                                                  ↪
# ↪  + (-2⋅lc₃⋅cos(q₁ + q₂ + q₃) - 2⋅lc₄⋅cos(q₁ + q₂ + q₃ + q₄))⋅(-lc₄⋅q_4_dot⋅sin(q₁ + q₂ + q₃ + q₄ ↪
#
# ↪                                                                                                  ↪
# ↪ ) + q_1_dot⋅(-lc₁⋅sin(q₁) - lc₂⋅sin(q₁ + q₂) - lc₃⋅sin(q₁ + q₂ + q₃) - lc₄⋅sin(q₁ + q₂ + q₃ + q₄ ↪
#
# ↪                                                                                                  ↪
# ↪ )) + q_2_dot⋅(-lc₂⋅sin(q₁ + q₂) - lc₃⋅sin(q₁ + q₂ + q₃) - lc₄⋅sin(q₁ + q₂ + q₃ + q₄)) + q_3_dot⋅ ↪
#
# ↪                                                                                                  ↪
# ↪ (-lc₃⋅sin(q₁ + q₂ + q₃) - lc₄⋅sin(q₁ + q₂ + q₃ + q₄))) + (-2⋅lc₁⋅sin(q₁) - 2⋅lc₂⋅sin(q₁ + q₂) -  ↪
#
# ↪                                                                                                  ↪
# ↪ 2⋅lc₃⋅sin(q₁ + q₂ + q₃) - 2⋅lc₄⋅sin(q₁ + q₂ + q₃ + q₄))⋅(-lc₄⋅q_4_dot⋅cos(q₁ + q₂ + q₃ + q₄) + q ↪
#
# ↪                                                                                                  ↪
# ↪ _1_dot⋅(-lc₃⋅cos(q₁ + q₂ + q₃) - lc₄⋅cos(q₁ + q₂ + q₃ + q₄)) + q_2_dot⋅(-lc₃⋅cos(q₁ + q₂ + q₃) - ↪
#
# ↪                                                                                                  ↪
# ↪  lc₄⋅cos(q₁ + q₂ + q₃ + q₄)) + q_3_dot⋅(-lc₃⋅cos(q₁ + q₂ + q₃) - lc₄⋅cos(q₁ + q₂ + q₃ + q₄))) +  ↪
#
# ↪                                                                                                  ↪
# ↪ (2⋅lc₁⋅cos(q₁) + 2⋅lc₂⋅cos(q₁ + q₂) + 2⋅lc₃⋅cos(q₁ + q₂ + q₃) + 2⋅lc₄⋅cos(q₁ + q₂ + q₃ + q₄))⋅(- ↪
#
# ↪                                                                                                  ↪
# ↪ lc₄⋅q_4_dot⋅sin(q₁ + q₂ + q₃ + q₄) + q_1_dot⋅(-lc₃⋅sin(q₁ + q₂ + q₃) - lc₄⋅sin(q₁ + q₂ + q₃ + q₄ ↪
#
# ↪                                                                                                  ↪
# ↪ )) + q_2_dot⋅(-lc₃⋅sin(q₁ + q₂ + q₃) - lc₄⋅sin(q₁ + q₂ + q₃ + q₄)) + q_3_dot⋅(-lc₃⋅sin(q₁ + q₂ + ↪
#
# ↪
# ↪  q₃) - lc₄⋅sin(q₁ + q₂ + q₃ + q₄))))) - τ₁
#
# Ecuación 2:
#                                                                                                    ↪
# g⋅m₂⋅(l₁ + lc₂)⋅cos(q₁ + q₂) + g⋅m₃⋅(l₁ + l₂ + lc₃)⋅cos(q₁ + q₂ + q₃) + g⋅m₄⋅(l₁ + l₂ + l₃ + lc₄)⋅ ↪
#
# ↪                                                                                                  ↪
# ↪ cos(q₁ + q₂ + q₃ + q₄) - 0.5⋅m₂⋅((-2⋅lc₂⋅q_1_dot⋅sin(q₁ + q₂) - 2⋅lc₂⋅q_2_dot⋅sin(q₁ + q₂))⋅(lc₂ ↪
#
# ↪                                                                                                  ↪
# ↪ ⋅q_2_dot⋅cos(q₁ + q₂) + q_1_dot⋅(lc₁⋅cos(q₁) + lc₂⋅cos(q₁ + q₂))) + (-2⋅lc₂⋅q_1_dot⋅cos(q₁ + q₂) ↪
#
# ↪                                                                                                  ↪
# ↪  - 2⋅lc₂⋅q_2_dot⋅cos(q₁ + q₂))⋅(-lc₂⋅q_2_dot⋅sin(q₁ + q₂) + q_1_dot⋅(-lc₁⋅sin(q₁) - lc₂⋅sin(q₁ + ↪
#
# ↪                                                                                                  ↪
# ↪  q₂)))) - 0.5⋅m₃⋅((-2⋅lc₃⋅q_3_dot⋅sin(q₁ + q₂ + q₃) + 2⋅q_1_dot⋅(-lc₂⋅sin(q₁ + q₂) - lc₃⋅sin(q₁  ↪
#
# ↪                                                                                                  ↪
# ↪ + q₂ + q₃)) + 2⋅q_2_dot⋅(-lc₂⋅sin(q₁ + q₂) - lc₃⋅sin(q₁ + q₂ + q₃)))⋅(lc₃⋅q_3_dot⋅cos(q₁ + q₂ +  ↪
#
# ↪                                                                                                  ↪
# ↪ q₃) + q_1_dot⋅(lc₁⋅cos(q₁) + lc₂⋅cos(q₁ + q₂) + lc₃⋅cos(q₁ + q₂ + q₃)) + q_2_dot⋅(lc₂⋅cos(q₁ + q ↪
#
# ↪                                                                                                  ↪
# ↪ ₂) + lc₃⋅cos(q₁ + q₂ + q₃))) + (-lc₃⋅q_3_dot⋅sin(q₁ + q₂ + q₃) + q_1_dot⋅(-lc₁⋅sin(q₁) - lc₂⋅sin ↪
#
# ↪                                                                                                  ↪
# ↪ (q₁ + q₂) - lc₃⋅sin(q₁ + q₂ + q₃)) + q_2_dot⋅(-lc₂⋅sin(q₁ + q₂) - lc₃⋅sin(q₁ + q₂ + q₃)))⋅(-2⋅lc ↪
#
# ↪                                                                                                  ↪
# ↪ ₃⋅q_3_dot⋅cos(q₁ + q₂ + q₃) + 2⋅q_1_dot⋅(-lc₂⋅cos(q₁ + q₂) - lc₃⋅cos(q₁ + q₂ + q₃)) + 2⋅q_2_dot⋅ ↪
#
# ↪                                                                                                  ↪
# ↪ (-lc₂⋅cos(q₁ + q₂) - lc₃⋅cos(q₁ + q₂ + q₃)))) + 0.5⋅m₄⋅q_4_dot⋅(-2⋅lc₄⋅(-lc₄⋅q_4_dot⋅sin(q₁ + q₂ ↪
#
# ↪                                                                                                  ↪
# ↪  + q₃ + q₄) + q_1_dot⋅(-lc₁⋅sin(q₁) - lc₂⋅sin(q₁ + q₂) - lc₃⋅sin(q₁ + q₂ + q₃) - lc₄⋅sin(q₁ + q₂ ↪
#
# ↪                                                                                                  ↪
# ↪  + q₃ + q₄)) + q_2_dot⋅(-lc₂⋅sin(q₁ + q₂) - lc₃⋅sin(q₁ + q₂ + q₃) - lc₄⋅sin(q₁ + q₂ + q₃ + q₄))  ↪
#
# ↪                                                                                                  ↪
# ↪ + q_3_dot⋅(-lc₃⋅sin(q₁ + q₂ + q₃) - lc₄⋅sin(q₁ + q₂ + q₃ + q₄)))⋅cos(q₁ + q₂ + q₃ + q₄) - 2⋅lc₄⋅ ↪
#
# ↪                                                                                                  ↪
# ↪ (lc₄⋅q_4_dot⋅cos(q₁ + q₂ + q₃ + q₄) + q_1_dot⋅(lc₁⋅cos(q₁) + lc₂⋅cos(q₁ + q₂) + lc₃⋅cos(q₁ + q₂  ↪
#
# ↪                                                                                                  ↪
# ↪ + q₃) + lc₄⋅cos(q₁ + q₂ + q₃ + q₄)) + q_2_dot⋅(lc₂⋅cos(q₁ + q₂) + lc₃⋅cos(q₁ + q₂ + q₃) + lc₄⋅co ↪
#
# ↪                                                                                                  ↪
# ↪ s(q₁ + q₂ + q₃ + q₄)) + q_3_dot⋅(lc₃⋅cos(q₁ + q₂ + q₃) + lc₄⋅cos(q₁ + q₂ + q₃ + q₄)))⋅sin(q₁ + q ↪
#
# ↪                                                                                                  ↪
# ↪ ₂ + q₃ + q₄) + (-2⋅lc₂⋅sin(q₁ + q₂) - 2⋅lc₃⋅sin(q₁ + q₂ + q₃) - 2⋅lc₄⋅sin(q₁ + q₂ + q₃ + q₄))⋅(- ↪
#
# ↪                                                                                                  ↪
# ↪ lc₄⋅q_1_dot⋅cos(q₁ + q₂ + q₃ + q₄) - lc₄⋅q_2_dot⋅cos(q₁ + q₂ + q₃ + q₄) - lc₄⋅q_3_dot⋅cos(q₁ + q ↪
#
# ↪                                                                                                  ↪
# ↪ ₂ + q₃ + q₄) - lc₄⋅q_4_dot⋅cos(q₁ + q₂ + q₃ + q₄)) + (2⋅lc₂⋅cos(q₁ + q₂) + 2⋅lc₃⋅cos(q₁ + q₂ + q ↪
#
# ↪                                                                                                  ↪
# ↪ ₃) + 2⋅lc₄⋅cos(q₁ + q₂ + q₃ + q₄))⋅(-lc₄⋅q_1_dot⋅sin(q₁ + q₂ + q₃ + q₄) - lc₄⋅q_2_dot⋅sin(q₁ + q ↪
#
# ↪                                                                                                  ↪
# ↪ ₂ + q₃ + q₄) - lc₄⋅q_3_dot⋅sin(q₁ + q₂ + q₃ + q₄) - lc₄⋅q_4_dot⋅sin(q₁ + q₂ + q₃ + q₄))) - 0.5⋅m ↪
#
# ↪                                                                                                  ↪
# ↪ ₄⋅((-2⋅lc₄⋅q_4_dot⋅sin(q₁ + q₂ + q₃ + q₄) + 2⋅q_1_dot⋅(-lc₂⋅sin(q₁ + q₂) - lc₃⋅sin(q₁ + q₂ + q₃) ↪
#
# ↪                                                                                                  ↪
# ↪  - lc₄⋅sin(q₁ + q₂ + q₃ + q₄)) + 2⋅q_2_dot⋅(-lc₂⋅sin(q₁ + q₂) - lc₃⋅sin(q₁ + q₂ + q₃) - lc₄⋅sin( ↪
#
# ↪                                                                                                  ↪
# ↪ q₁ + q₂ + q₃ + q₄)) + 2⋅q_3_dot⋅(-lc₃⋅sin(q₁ + q₂ + q₃) - lc₄⋅sin(q₁ + q₂ + q₃ + q₄)))⋅(lc₄⋅q_4_ ↪
#
# ↪                                                                                                  ↪
# ↪ dot⋅cos(q₁ + q₂ + q₃ + q₄) + q_1_dot⋅(lc₁⋅cos(q₁) + lc₂⋅cos(q₁ + q₂) + lc₃⋅cos(q₁ + q₂ + q₃) + l ↪
#
# ↪                                                                                                  ↪
# ↪ c₄⋅cos(q₁ + q₂ + q₃ + q₄)) + q_2_dot⋅(lc₂⋅cos(q₁ + q₂) + lc₃⋅cos(q₁ + q₂ + q₃) + lc₄⋅cos(q₁ + q₂ ↪
#
# ↪                                                                                                  ↪
# ↪  + q₃ + q₄)) + q_3_dot⋅(lc₃⋅cos(q₁ + q₂ + q₃) + lc₄⋅cos(q₁ + q₂ + q₃ + q₄))) + (-lc₄⋅q_4_dot⋅sin ↪
#
# ↪                                                                                                  ↪
# ↪ (q₁ + q₂ + q₃ + q₄) + q_1_dot⋅(-lc₁⋅sin(q₁) - lc₂⋅sin(q₁ + q₂) - lc₃⋅sin(q₁ + q₂ + q₃) - lc₄⋅sin ↪
#
# ↪                                                                                                  ↪
# ↪ (q₁ + q₂ + q₃ + q₄)) + q_2_dot⋅(-lc₂⋅sin(q₁ + q₂) - lc₃⋅sin(q₁ + q₂ + q₃) - lc₄⋅sin(q₁ + q₂ + q₃ ↪
#
# ↪                                                                                                  ↪
# ↪  + q₄)) + q_3_dot⋅(-lc₃⋅sin(q₁ + q₂ + q₃) - lc₄⋅sin(q₁ + q₂ + q₃ + q₄)))⋅(-2⋅lc₄⋅q_4_dot⋅cos(q₁  ↪
#
# ↪                                                                                                  ↪
# ↪ + q₂ + q₃ + q₄) + 2⋅q_1_dot⋅(-lc₂⋅cos(q₁ + q₂) - lc₃⋅cos(q₁ + q₂ + q₃) - lc₄⋅cos(q₁ + q₂ + q₃ +  ↪
#
# ↪                                                                                                  ↪
# ↪ q₄)) + 2⋅q_2_dot⋅(-lc₂⋅cos(q₁ + q₂) - lc₃⋅cos(q₁ + q₂ + q₃) - lc₄⋅cos(q₁ + q₂ + q₃ + q₄)) + 2⋅q_ ↪
#
# ↪                                                                                                  ↪
# ↪ 3_dot⋅(-lc₃⋅cos(q₁ + q₂ + q₃) - lc₄⋅cos(q₁ + q₂ + q₃ + q₄)))) + q_1_dot⋅(0.5⋅m₂⋅(-2⋅lc₂⋅(-lc₂⋅q_ ↪
#
# ↪                                                                                                  ↪
# ↪ 2_dot⋅cos(q₁ + q₂) + q_1_dot⋅(-lc₁⋅cos(q₁) - lc₂⋅cos(q₁ + q₂)))⋅sin(q₁ + q₂) - 2⋅lc₂⋅(lc₂⋅q_2_do ↪
#
# ↪                                                                                                  ↪
# ↪ t⋅cos(q₁ + q₂) + q_1_dot⋅(lc₁⋅cos(q₁) + lc₂⋅cos(q₁ + q₂)))⋅sin(q₁ + q₂)) + 0.5⋅m₃⋅((-2⋅lc₂⋅sin(q ↪
#
# ↪                                                                                                  ↪
# ↪ ₁ + q₂) - 2⋅lc₃⋅sin(q₁ + q₂ + q₃))⋅(-lc₃⋅q_3_dot⋅cos(q₁ + q₂ + q₃) + q_1_dot⋅(-lc₁⋅cos(q₁) - lc₂ ↪
#
# ↪                                                                                                  ↪
# ↪ ⋅cos(q₁ + q₂) - lc₃⋅cos(q₁ + q₂ + q₃)) + q_2_dot⋅(-lc₂⋅cos(q₁ + q₂) - lc₃⋅cos(q₁ + q₂ + q₃))) +  ↪
#
# ↪                                                                                                  ↪
# ↪ (-2⋅lc₂⋅sin(q₁ + q₂) - 2⋅lc₃⋅sin(q₁ + q₂ + q₃))⋅(lc₃⋅q_3_dot⋅cos(q₁ + q₂ + q₃) + q_1_dot⋅(lc₁⋅co ↪
#
# ↪                                                                                                  ↪
# ↪ s(q₁) + lc₂⋅cos(q₁ + q₂) + lc₃⋅cos(q₁ + q₂ + q₃)) + q_2_dot⋅(lc₂⋅cos(q₁ + q₂) + lc₃⋅cos(q₁ + q₂  ↪
#
# ↪                                                                                                  ↪
# ↪ + q₃))) + (-2⋅lc₂⋅cos(q₁ + q₂) - 2⋅lc₃⋅cos(q₁ + q₂ + q₃))⋅(-lc₃⋅q_3_dot⋅sin(q₁ + q₂ + q₃) + q_1_ ↪
#
# ↪                                                                                                  ↪
# ↪ dot⋅(-lc₁⋅sin(q₁) - lc₂⋅sin(q₁ + q₂) - lc₃⋅sin(q₁ + q₂ + q₃)) + q_2_dot⋅(-lc₂⋅sin(q₁ + q₂) - lc₃ ↪
#
# ↪                                                                                                  ↪
# ↪ ⋅sin(q₁ + q₂ + q₃))) + (2⋅lc₂⋅cos(q₁ + q₂) + 2⋅lc₃⋅cos(q₁ + q₂ + q₃))⋅(-lc₃⋅q_3_dot⋅sin(q₁ + q₂  ↪
#
# ↪                                                                                                  ↪
# ↪ + q₃) + q_1_dot⋅(-lc₁⋅sin(q₁) - lc₂⋅sin(q₁ + q₂) - lc₃⋅sin(q₁ + q₂ + q₃)) + q_2_dot⋅(-lc₂⋅sin(q₁ ↪
#
# ↪                                                                                                  ↪
# ↪  + q₂) - lc₃⋅sin(q₁ + q₂ + q₃)))) + 0.5⋅m₄⋅((-2⋅lc₂⋅sin(q₁ + q₂) - 2⋅lc₃⋅sin(q₁ + q₂ + q₃) - 2⋅l ↪
#
# ↪                                                                                                  ↪
# ↪ c₄⋅sin(q₁ + q₂ + q₃ + q₄))⋅(-lc₄⋅q_4_dot⋅cos(q₁ + q₂ + q₃ + q₄) + q_1_dot⋅(-lc₁⋅cos(q₁) - lc₂⋅co ↪
#
# ↪                                                                                                  ↪
# ↪ s(q₁ + q₂) - lc₃⋅cos(q₁ + q₂ + q₃) - lc₄⋅cos(q₁ + q₂ + q₃ + q₄)) + q_2_dot⋅(-lc₂⋅cos(q₁ + q₂) -  ↪
#
# ↪                                                                                                  ↪
# ↪ lc₃⋅cos(q₁ + q₂ + q₃) - lc₄⋅cos(q₁ + q₂ + q₃ + q₄)) + q_3_dot⋅(-lc₃⋅cos(q₁ + q₂ + q₃) - lc₄⋅cos( ↪
#
# ↪                                                                                                  ↪
# ↪ q₁ + q₂ + q₃ + q₄))) + (-2⋅lc₂⋅sin(q₁ + q₂) - 2⋅lc₃⋅sin(q₁ + q₂ + q₃) - 2⋅lc₄⋅sin(q₁ + q₂ + q₃ + ↪
#
# ↪                                                                                                  ↪
# ↪  q₄))⋅(lc₄⋅q_4_dot⋅cos(q₁ + q₂ + q₃ + q₄) + q_1_dot⋅(lc₁⋅cos(q₁) + lc₂⋅cos(q₁ + q₂) + lc₃⋅cos(q₁ ↪
#
# ↪                                                                                                  ↪
# ↪  + q₂ + q₃) + lc₄⋅cos(q₁ + q₂ + q₃ + q₄)) + q_2_dot⋅(lc₂⋅cos(q₁ + q₂) + lc₃⋅cos(q₁ + q₂ + q₃) +  ↪
#
# ↪                                                                                                  ↪
# ↪ lc₄⋅cos(q₁ + q₂ + q₃ + q₄)) + q_3_dot⋅(lc₃⋅cos(q₁ + q₂ + q₃) + lc₄⋅cos(q₁ + q₂ + q₃ + q₄))) + (- ↪
#
# ↪                                                                                                  ↪
# ↪ 2⋅lc₂⋅cos(q₁ + q₂) - 2⋅lc₃⋅cos(q₁ + q₂ + q₃) - 2⋅lc₄⋅cos(q₁ + q₂ + q₃ + q₄))⋅(-lc₄⋅q_4_dot⋅sin(q ↪
#
# ↪                                                                                                  ↪
# ↪ ₁ + q₂ + q₃ + q₄) + q_1_dot⋅(-lc₁⋅sin(q₁) - lc₂⋅sin(q₁ + q₂) - lc₃⋅sin(q₁ + q₂ + q₃) - lc₄⋅sin(q ↪
#
# ↪                                                                                                  ↪
# ↪ ₁ + q₂ + q₃ + q₄)) + q_2_dot⋅(-lc₂⋅sin(q₁ + q₂) - lc₃⋅sin(q₁ + q₂ + q₃) - lc₄⋅sin(q₁ + q₂ + q₃ + ↪
#
# ↪                                                                                                  ↪
# ↪  q₄)) + q_3_dot⋅(-lc₃⋅sin(q₁ + q₂ + q₃) - lc₄⋅sin(q₁ + q₂ + q₃ + q₄))) + (2⋅lc₂⋅cos(q₁ + q₂) + 2 ↪
#
# ↪                                                                                                  ↪
# ↪ ⋅lc₃⋅cos(q₁ + q₂ + q₃) + 2⋅lc₄⋅cos(q₁ + q₂ + q₃ + q₄))⋅(-lc₄⋅q_4_dot⋅sin(q₁ + q₂ + q₃ + q₄) + q_ ↪
#
# ↪                                                                                                  ↪
# ↪ 1_dot⋅(-lc₁⋅sin(q₁) - lc₂⋅sin(q₁ + q₂) - lc₃⋅sin(q₁ + q₂ + q₃) - lc₄⋅sin(q₁ + q₂ + q₃ + q₄)) + q ↪
#
# ↪                                                                                                  ↪
# ↪ _2_dot⋅(-lc₂⋅sin(q₁ + q₂) - lc₃⋅sin(q₁ + q₂ + q₃) - lc₄⋅sin(q₁ + q₂ + q₃ + q₄)) + q_3_dot⋅(-lc₃⋅ ↪
#
# ↪                                                            ⎛                                  ⎛  ↪
# ↪ sin(q₁ + q₂ + q₃) - lc₄⋅sin(q₁ + q₂ + q₃ + q₄))))) + q_2_ḋ⋅⎝1.0⋅I₂ + 1.0⋅I₃ + 1.0⋅I₄ + 0.5⋅m₂⋅⎝2 ↪
#
# ↪     2    2                 2    2         ⎞                                                      ↪
# ↪ ⋅lc₂ ⋅sin (q₁ + q₂) + 2⋅lc₂ ⋅cos (q₁ + q₂)⎠ + 0.5⋅m₃⋅((-2⋅lc₂⋅sin(q₁ + q₂) - 2⋅lc₃⋅sin(q₁ + q₂ + ↪
#
# ↪                                                                                                  ↪
# ↪  q₃))⋅(-lc₂⋅sin(q₁ + q₂) - lc₃⋅sin(q₁ + q₂ + q₃)) + (lc₂⋅cos(q₁ + q₂) + lc₃⋅cos(q₁ + q₂ + q₃))⋅( ↪
#
# ↪                                                                                                  ↪
# ↪ 2⋅lc₂⋅cos(q₁ + q₂) + 2⋅lc₃⋅cos(q₁ + q₂ + q₃))) + 0.5⋅m₄⋅((-2⋅lc₂⋅sin(q₁ + q₂) - 2⋅lc₃⋅sin(q₁ + q ↪
#
# ↪                                                                                                  ↪
# ↪ ₂ + q₃) - 2⋅lc₄⋅sin(q₁ + q₂ + q₃ + q₄))⋅(-lc₂⋅sin(q₁ + q₂) - lc₃⋅sin(q₁ + q₂ + q₃) - lc₄⋅sin(q₁  ↪
#
# ↪                                                                                                  ↪
# ↪ + q₂ + q₃ + q₄)) + (lc₂⋅cos(q₁ + q₂) + lc₃⋅cos(q₁ + q₂ + q₃) + lc₄⋅cos(q₁ + q₂ + q₃ + q₄))⋅(2⋅lc ↪
#
# ↪                                                                          ⎞                       ↪
# ↪ ₂⋅cos(q₁ + q₂) + 2⋅lc₃⋅cos(q₁ + q₂ + q₃) + 2⋅lc₄⋅cos(q₁ + q₂ + q₃ + q₄)))⎠ + q_2_dot⋅(0.5⋅m₂⋅(2⋅ ↪
#
# ↪                                                                                                  ↪
# ↪ lc₂⋅(-lc₂⋅q_1_dot⋅sin(q₁ + q₂) - lc₂⋅q_2_dot⋅sin(q₁ + q₂))⋅cos(q₁ + q₂) - 2⋅lc₂⋅(-lc₂⋅q_1_dot⋅co ↪
#
# ↪                                                                                                  ↪
# ↪ s(q₁ + q₂) - lc₂⋅q_2_dot⋅cos(q₁ + q₂))⋅sin(q₁ + q₂) - 2⋅lc₂⋅(-lc₂⋅q_2_dot⋅sin(q₁ + q₂) + q_1_dot ↪
#
# ↪                                                                                                  ↪
# ↪ ⋅(-lc₁⋅sin(q₁) - lc₂⋅sin(q₁ + q₂)))⋅cos(q₁ + q₂) - 2⋅lc₂⋅(lc₂⋅q_2_dot⋅cos(q₁ + q₂) + q_1_dot⋅(lc ↪
#
# ↪                                                                                                  ↪
# ↪ ₁⋅cos(q₁) + lc₂⋅cos(q₁ + q₂)))⋅sin(q₁ + q₂)) + 0.5⋅m₃⋅((-2⋅lc₂⋅sin(q₁ + q₂) - 2⋅lc₃⋅sin(q₁ + q₂  ↪
#
# ↪                                                                                                  ↪
# ↪ + q₃))⋅(-lc₃⋅q_3_dot⋅cos(q₁ + q₂ + q₃) + q_1_dot⋅(-lc₂⋅cos(q₁ + q₂) - lc₃⋅cos(q₁ + q₂ + q₃)) + q ↪
#
# ↪                                                                                                  ↪
# ↪ _2_dot⋅(-lc₂⋅cos(q₁ + q₂) - lc₃⋅cos(q₁ + q₂ + q₃))) + (-2⋅lc₂⋅sin(q₁ + q₂) - 2⋅lc₃⋅sin(q₁ + q₂ + ↪
#
# ↪                                                                                                  ↪
# ↪  q₃))⋅(lc₃⋅q_3_dot⋅cos(q₁ + q₂ + q₃) + q_1_dot⋅(lc₁⋅cos(q₁) + lc₂⋅cos(q₁ + q₂) + lc₃⋅cos(q₁ + q₂ ↪
#
# ↪                                                                                                  ↪
# ↪  + q₃)) + q_2_dot⋅(lc₂⋅cos(q₁ + q₂) + lc₃⋅cos(q₁ + q₂ + q₃))) + (-2⋅lc₂⋅cos(q₁ + q₂) - 2⋅lc₃⋅cos ↪
#
# ↪                                                                                                  ↪
# ↪ (q₁ + q₂ + q₃))⋅(-lc₃⋅q_3_dot⋅sin(q₁ + q₂ + q₃) + q_1_dot⋅(-lc₁⋅sin(q₁) - lc₂⋅sin(q₁ + q₂) - lc₃ ↪
#
# ↪                                                                                                  ↪
# ↪ ⋅sin(q₁ + q₂ + q₃)) + q_2_dot⋅(-lc₂⋅sin(q₁ + q₂) - lc₃⋅sin(q₁ + q₂ + q₃))) + (2⋅lc₂⋅cos(q₁ + q₂) ↪
#
# ↪                                                                                                  ↪
# ↪  + 2⋅lc₃⋅cos(q₁ + q₂ + q₃))⋅(-lc₃⋅q_3_dot⋅sin(q₁ + q₂ + q₃) + q_1_dot⋅(-lc₂⋅sin(q₁ + q₂) - lc₃⋅s ↪
#
# ↪                                                                                                  ↪
# ↪ in(q₁ + q₂ + q₃)) + q_2_dot⋅(-lc₂⋅sin(q₁ + q₂) - lc₃⋅sin(q₁ + q₂ + q₃)))) + 0.5⋅m₄⋅((-2⋅lc₂⋅sin( ↪
#
# ↪                                                                                                  ↪
# ↪ q₁ + q₂) - 2⋅lc₃⋅sin(q₁ + q₂ + q₃) - 2⋅lc₄⋅sin(q₁ + q₂ + q₃ + q₄))⋅(-lc₄⋅q_4_dot⋅cos(q₁ + q₂ + q ↪
#
# ↪                                                                                                  ↪
# ↪ ₃ + q₄) + q_1_dot⋅(-lc₂⋅cos(q₁ + q₂) - lc₃⋅cos(q₁ + q₂ + q₃) - lc₄⋅cos(q₁ + q₂ + q₃ + q₄)) + q_2 ↪
#
# ↪                                                                                                  ↪
# ↪ _dot⋅(-lc₂⋅cos(q₁ + q₂) - lc₃⋅cos(q₁ + q₂ + q₃) - lc₄⋅cos(q₁ + q₂ + q₃ + q₄)) + q_3_dot⋅(-lc₃⋅co ↪
#
# ↪                                                                                                  ↪
# ↪ s(q₁ + q₂ + q₃) - lc₄⋅cos(q₁ + q₂ + q₃ + q₄))) + (-2⋅lc₂⋅sin(q₁ + q₂) - 2⋅lc₃⋅sin(q₁ + q₂ + q₃)  ↪
#
# ↪                                                                                                  ↪
# ↪ - 2⋅lc₄⋅sin(q₁ + q₂ + q₃ + q₄))⋅(lc₄⋅q_4_dot⋅cos(q₁ + q₂ + q₃ + q₄) + q_1_dot⋅(lc₁⋅cos(q₁) + lc₂ ↪
#
# ↪                                                                                                  ↪
# ↪ ⋅cos(q₁ + q₂) + lc₃⋅cos(q₁ + q₂ + q₃) + lc₄⋅cos(q₁ + q₂ + q₃ + q₄)) + q_2_dot⋅(lc₂⋅cos(q₁ + q₂)  ↪
#
# ↪                                                                                                  ↪
# ↪ + lc₃⋅cos(q₁ + q₂ + q₃) + lc₄⋅cos(q₁ + q₂ + q₃ + q₄)) + q_3_dot⋅(lc₃⋅cos(q₁ + q₂ + q₃) + lc₄⋅cos ↪
#
# ↪                                                                                                  ↪
# ↪ (q₁ + q₂ + q₃ + q₄))) + (-2⋅lc₂⋅cos(q₁ + q₂) - 2⋅lc₃⋅cos(q₁ + q₂ + q₃) - 2⋅lc₄⋅cos(q₁ + q₂ + q₃  ↪
#
# ↪                                                                                                  ↪
# ↪ + q₄))⋅(-lc₄⋅q_4_dot⋅sin(q₁ + q₂ + q₃ + q₄) + q_1_dot⋅(-lc₁⋅sin(q₁) - lc₂⋅sin(q₁ + q₂) - lc₃⋅sin ↪
#
# ↪                                                                                                  ↪
# ↪ (q₁ + q₂ + q₃) - lc₄⋅sin(q₁ + q₂ + q₃ + q₄)) + q_2_dot⋅(-lc₂⋅sin(q₁ + q₂) - lc₃⋅sin(q₁ + q₂ + q₃ ↪
#
# ↪                                                                                                  ↪
# ↪ ) - lc₄⋅sin(q₁ + q₂ + q₃ + q₄)) + q_3_dot⋅(-lc₃⋅sin(q₁ + q₂ + q₃) - lc₄⋅sin(q₁ + q₂ + q₃ + q₄))) ↪
#
# ↪                                                                                                  ↪
# ↪  + (2⋅lc₂⋅cos(q₁ + q₂) + 2⋅lc₃⋅cos(q₁ + q₂ + q₃) + 2⋅lc₄⋅cos(q₁ + q₂ + q₃ + q₄))⋅(-lc₄⋅q_4_dot⋅s ↪
#
# ↪                                                                                                  ↪
# ↪ in(q₁ + q₂ + q₃ + q₄) + q_1_dot⋅(-lc₂⋅sin(q₁ + q₂) - lc₃⋅sin(q₁ + q₂ + q₃) - lc₄⋅sin(q₁ + q₂ + q ↪
#
# ↪                                                                                                  ↪
# ↪ ₃ + q₄)) + q_2_dot⋅(-lc₂⋅sin(q₁ + q₂) - lc₃⋅sin(q₁ + q₂ + q₃) - lc₄⋅sin(q₁ + q₂ + q₃ + q₄)) + q_ ↪
#
# ↪                                                                                                  ↪
# ↪ 3_dot⋅(-lc₃⋅sin(q₁ + q₂ + q₃) - lc₄⋅sin(q₁ + q₂ + q₃ + q₄))))) + q_3_dot⋅(0.5⋅m₃⋅(-2⋅lc₃⋅(-lc₃⋅q ↪
#
# ↪                                                                                                  ↪
# ↪ _3_dot⋅sin(q₁ + q₂ + q₃) + q_1_dot⋅(-lc₁⋅sin(q₁) - lc₂⋅sin(q₁ + q₂) - lc₃⋅sin(q₁ + q₂ + q₃)) + q ↪
#
# ↪                                                                                                  ↪
# ↪ _2_dot⋅(-lc₂⋅sin(q₁ + q₂) - lc₃⋅sin(q₁ + q₂ + q₃)))⋅cos(q₁ + q₂ + q₃) - 2⋅lc₃⋅(lc₃⋅q_3_dot⋅cos(q ↪
#
# ↪                                                                                                  ↪
# ↪ ₁ + q₂ + q₃) + q_1_dot⋅(lc₁⋅cos(q₁) + lc₂⋅cos(q₁ + q₂) + lc₃⋅cos(q₁ + q₂ + q₃)) + q_2_dot⋅(lc₂⋅c ↪
#
# ↪                                                                                                  ↪
# ↪ os(q₁ + q₂) + lc₃⋅cos(q₁ + q₂ + q₃)))⋅sin(q₁ + q₂ + q₃) + (-2⋅lc₂⋅sin(q₁ + q₂) - 2⋅lc₃⋅sin(q₁ +  ↪
#
# ↪                                                                                                  ↪
# ↪ q₂ + q₃))⋅(-lc₃⋅q_1_dot⋅cos(q₁ + q₂ + q₃) - lc₃⋅q_2_dot⋅cos(q₁ + q₂ + q₃) - lc₃⋅q_3_dot⋅cos(q₁ + ↪
#
# ↪                                                                                                  ↪
# ↪  q₂ + q₃)) + (2⋅lc₂⋅cos(q₁ + q₂) + 2⋅lc₃⋅cos(q₁ + q₂ + q₃))⋅(-lc₃⋅q_1_dot⋅sin(q₁ + q₂ + q₃) - lc ↪
#
# ↪                                                                                                  ↪
# ↪ ₃⋅q_2_dot⋅sin(q₁ + q₂ + q₃) - lc₃⋅q_3_dot⋅sin(q₁ + q₂ + q₃))) + 0.5⋅m₄⋅((-2⋅lc₃⋅sin(q₁ + q₂ + q₃ ↪
#
# ↪                                                                                                  ↪
# ↪ ) - 2⋅lc₄⋅sin(q₁ + q₂ + q₃ + q₄))⋅(lc₄⋅q_4_dot⋅cos(q₁ + q₂ + q₃ + q₄) + q_1_dot⋅(lc₁⋅cos(q₁) + l ↪
#
# ↪                                                                                                  ↪
# ↪ c₂⋅cos(q₁ + q₂) + lc₃⋅cos(q₁ + q₂ + q₃) + lc₄⋅cos(q₁ + q₂ + q₃ + q₄)) + q_2_dot⋅(lc₂⋅cos(q₁ + q₂ ↪
#
# ↪                                                                                                  ↪
# ↪ ) + lc₃⋅cos(q₁ + q₂ + q₃) + lc₄⋅cos(q₁ + q₂ + q₃ + q₄)) + q_3_dot⋅(lc₃⋅cos(q₁ + q₂ + q₃) + lc₄⋅c ↪
#
# ↪                                                                                                  ↪
# ↪ os(q₁ + q₂ + q₃ + q₄))) + (-2⋅lc₃⋅cos(q₁ + q₂ + q₃) - 2⋅lc₄⋅cos(q₁ + q₂ + q₃ + q₄))⋅(-lc₄⋅q_4_do ↪
#
# ↪                                                                                                  ↪
# ↪ t⋅sin(q₁ + q₂ + q₃ + q₄) + q_1_dot⋅(-lc₁⋅sin(q₁) - lc₂⋅sin(q₁ + q₂) - lc₃⋅sin(q₁ + q₂ + q₃) - lc ↪
#
# ↪                                                                                                  ↪
# ↪ ₄⋅sin(q₁ + q₂ + q₃ + q₄)) + q_2_dot⋅(-lc₂⋅sin(q₁ + q₂) - lc₃⋅sin(q₁ + q₂ + q₃) - lc₄⋅sin(q₁ + q₂ ↪
#
# ↪                                                                                                  ↪
# ↪  + q₃ + q₄)) + q_3_dot⋅(-lc₃⋅sin(q₁ + q₂ + q₃) - lc₄⋅sin(q₁ + q₂ + q₃ + q₄))) + (-2⋅lc₂⋅sin(q₁ + ↪
#
# ↪                                                                                                  ↪
# ↪  q₂) - 2⋅lc₃⋅sin(q₁ + q₂ + q₃) - 2⋅lc₄⋅sin(q₁ + q₂ + q₃ + q₄))⋅(-lc₄⋅q_4_dot⋅cos(q₁ + q₂ + q₃ +  ↪
#
# ↪                                                                                                  ↪
# ↪ q₄) + q_1_dot⋅(-lc₃⋅cos(q₁ + q₂ + q₃) - lc₄⋅cos(q₁ + q₂ + q₃ + q₄)) + q_2_dot⋅(-lc₃⋅cos(q₁ + q₂  ↪
#
# ↪                                                                                                  ↪
# ↪ + q₃) - lc₄⋅cos(q₁ + q₂ + q₃ + q₄)) + q_3_dot⋅(-lc₃⋅cos(q₁ + q₂ + q₃) - lc₄⋅cos(q₁ + q₂ + q₃ + q ↪
#
# ↪                                                                                                  ↪
# ↪ ₄))) + (2⋅lc₂⋅cos(q₁ + q₂) + 2⋅lc₃⋅cos(q₁ + q₂ + q₃) + 2⋅lc₄⋅cos(q₁ + q₂ + q₃ + q₄))⋅(-lc₄⋅q_4_d ↪
#
# ↪                                                                                                  ↪
# ↪ ot⋅sin(q₁ + q₂ + q₃ + q₄) + q_1_dot⋅(-lc₃⋅sin(q₁ + q₂ + q₃) - lc₄⋅sin(q₁ + q₂ + q₃ + q₄)) + q_2_ ↪
#
# ↪                                                                                                  ↪
# ...
#
# ↪                                                                                                  ↪
# ↪ n(q₁ + q₂ + q₃ + q₄) + q_1_dot⋅(-lc₁⋅sin(q₁) - lc₂⋅sin(q₁ + q₂) - lc₃⋅sin(q₁ + q₂ + q₃) - lc₄⋅si ↪
#
# ↪                                                                                                  ↪
# ↪ n(q₁ + q₂ + q₃ + q₄)) + q_2_dot⋅(-lc₂⋅sin(q₁ + q₂) - lc₃⋅sin(q₁ + q₂ + q₃) - lc₄⋅sin(q₁ + q₂ + q ↪
#
# ↪                                                                                    ⎛             ↪
# ↪ ₃ + q₄)) + q_3_dot⋅(-lc₃⋅sin(q₁ + q₂ + q₃) - lc₄⋅sin(q₁ + q₂ + q₃ + q₄)))) + q_4_ḋ⋅⎝1.0⋅I₄ + 0.5 ↪
#
# ↪     ⎛     2    2                           2    2                   ⎞⎞
# ↪ ⋅m₄⋅⎝2⋅lc₄ ⋅sin (q₁ + q₂ + q₃ + q₄) + 2⋅lc₄ ⋅cos (q₁ + q₂ + q₃ + q₄)⎠⎠ - τ₄
#
#
# Ecuaciones simplificadas:
# Ecuación 1:
#                                                                                                    ↪
# g⋅lc₁⋅m₁⋅cos(q₁) + g⋅m₂⋅(l₁ + lc₂)⋅cos(q₁ + q₂) + g⋅m₃⋅(l₁ + l₂ + lc₃)⋅cos(q₁ + q₂ + q₃) + g⋅m₄⋅(l ↪
#
# ↪                                                                                                  ↪
# ↪ ₁ + l₂ + l₃ + lc₄)⋅cos(q₁ + q₂ + q₃ + q₄) - 1.0⋅lc₁⋅q_2_dot⋅(lc₂⋅m₂⋅(2⋅q_1_dot + q_2_dot)⋅sin(q₂ ↪
#
# ↪                                                                                                  ↪
# ↪ ) + m₃⋅(2⋅lc₂⋅q_1_dot⋅sin(q₂) + lc₂⋅q_2_dot⋅sin(q₂) + 2⋅lc₃⋅q_1_dot⋅sin(q₂ + q₃) + lc₃⋅q_2_dot⋅s ↪
#
# ↪                                                                                                  ↪
# ↪ in(q₂ + q₃) + lc₃⋅q_3_dot⋅sin(q₂ + q₃)) + m₄⋅(2⋅lc₂⋅q_1_dot⋅sin(q₂) + lc₂⋅q_2_dot⋅sin(q₂) + 2⋅lc ↪
#
# ↪                                                                                                  ↪
# ↪ ₃⋅q_1_dot⋅sin(q₂ + q₃) + lc₃⋅q_2_dot⋅sin(q₂ + q₃) + lc₃⋅q_3_dot⋅sin(q₂ + q₃) + 2⋅lc₄⋅q_1_dot⋅sin ↪
#
# ↪                                                                                                  ↪
# ↪ (q₂ + q₃ + q₄) + lc₄⋅q_2_dot⋅sin(q₂ + q₃ + q₄) + lc₄⋅q_3_dot⋅sin(q₂ + q₃ + q₄) + lc₄⋅q_4_dot⋅sin ↪
#
# ↪                                                                                                  ↪
# ↪ (q₂ + q₃ + q₄))) - 1.0⋅lc₄⋅m₄⋅q_4_dot⋅(2⋅lc₁⋅q_1_dot⋅sin(q₂ + q₃ + q₄) + lc₁⋅q_2_dot⋅sin(q₂ + q₃ ↪
#
# ↪                                                                                                  ↪
# ↪  + q₄) + lc₁⋅q_3_dot⋅sin(q₂ + q₃ + q₄) + lc₁⋅q_4_dot⋅sin(q₂ + q₃ + q₄) + 2⋅lc₂⋅q_1_dot⋅sin(q₃ +  ↪
#
# ↪                                                                                                  ↪
# ↪ q₄) + 2⋅lc₂⋅q_2_dot⋅sin(q₃ + q₄) + lc₂⋅q_3_dot⋅sin(q₃ + q₄) + lc₂⋅q_4_dot⋅sin(q₃ + q₄) + 2⋅lc₃⋅q ↪
#
# ↪                                                                                                  ↪
# ↪ _1_dot⋅sin(q₄) + 2⋅lc₃⋅q_2_dot⋅sin(q₄) + 2⋅lc₃⋅q_3_dot⋅sin(q₄) + lc₃⋅q_4_dot⋅sin(q₄)) + 1.0⋅q_1_ ↪
#
# ↪   ⎛                       2         ⎛   2                          2⎞      ⎛   2                 ↪
# ↪ ḋ⋅⎝I₁ + I₂ + I₃ + I₄ + lc₁ ⋅m₁ + m₂⋅⎝lc₁  + 2⋅lc₁⋅lc₂⋅cos(q₂) + lc₂ ⎠ + m₃⋅⎝lc₁  + 2⋅lc₁⋅lc₂⋅cos ↪
#
# ↪                                    2                          2⎞      ⎛   2                      ↪
# ↪ (q₂) + 2⋅lc₁⋅lc₃⋅cos(q₂ + q₃) + lc₂  + 2⋅lc₂⋅lc₃⋅cos(q₃) + lc₃ ⎠ + m₄⋅⎝lc₁  + 2⋅lc₁⋅lc₂⋅cos(q₂)  ↪
#
# ↪                                                             2                                    ↪
# ↪ + 2⋅lc₁⋅lc₃⋅cos(q₂ + q₃) + 2⋅lc₁⋅lc₄⋅cos(q₂ + q₃ + q₄) + lc₂  + 2⋅lc₂⋅lc₃⋅cos(q₃) + 2⋅lc₂⋅lc₄⋅co ↪
#
# ↪                 2                          2⎞⎞                                                   ↪
# ↪ s(q₃ + q₄) + lc₃  + 2⋅lc₃⋅lc₄⋅cos(q₄) + lc₄ ⎠⎠ - 1.0⋅q_3_dot⋅(lc₃⋅m₃⋅(2⋅lc₁⋅q_1_dot⋅sin(q₂ + q₃) ↪
#
# ↪                                                                                                  ↪
# ↪  + lc₁⋅q_2_dot⋅sin(q₂ + q₃) + lc₁⋅q_3_dot⋅sin(q₂ + q₃) + 2⋅lc₂⋅q_1_dot⋅sin(q₃) + 2⋅lc₂⋅q_2_dot⋅s ↪
#
# ↪                                                                                                  ↪
# ↪ in(q₃) + lc₂⋅q_3_dot⋅sin(q₃)) + m₄⋅(2⋅lc₁⋅lc₃⋅q_1_dot⋅sin(q₂ + q₃) + lc₁⋅lc₃⋅q_2_dot⋅sin(q₂ + q₃ ↪
#
# ↪                                                                                                  ↪
# ↪ ) + lc₁⋅lc₃⋅q_3_dot⋅sin(q₂ + q₃) + 2⋅lc₁⋅lc₄⋅q_1_dot⋅sin(q₂ + q₃ + q₄) + lc₁⋅lc₄⋅q_2_dot⋅sin(q₂  ↪
#
# ↪                                                                                                  ↪
# ↪ + q₃ + q₄) + lc₁⋅lc₄⋅q_3_dot⋅sin(q₂ + q₃ + q₄) + lc₁⋅lc₄⋅q_4_dot⋅sin(q₂ + q₃ + q₄) + 2⋅lc₂⋅lc₃⋅q ↪
#
# ↪                                                                                                  ↪
# ↪ _1_dot⋅sin(q₃) + 2⋅lc₂⋅lc₃⋅q_2_dot⋅sin(q₃) + lc₂⋅lc₃⋅q_3_dot⋅sin(q₃) + 2⋅lc₂⋅lc₄⋅q_1_dot⋅sin(q₃  ↪
#
# ↪                                                                                                  ↪
# ↪ + q₄) + 2⋅lc₂⋅lc₄⋅q_2_dot⋅sin(q₃ + q₄) + lc₂⋅lc₄⋅q_3_dot⋅sin(q₃ + q₄) + lc₂⋅lc₄⋅q_4_dot⋅sin(q₃ + ↪
#
# ↪
# ↪  q₄))) - τ₁
#
# Ecuación 2:
#                                                                                                    ↪
# 1.0⋅I₂⋅q_2_ḋ + 1.0⋅I₃⋅q_2_ḋ + 1.0⋅I₄⋅q_2_ḋ + 1.0⋅g⋅l₁⋅m₂⋅cos(q₁ + q₂) + 1.0⋅g⋅l₁⋅m₃⋅cos(q₁ + q₂ +  ↪
#
# ↪                                                                                                  ↪
# ↪ q₃) - 1.0⋅g⋅l₁⋅m₄⋅sin(q₁)⋅sin(q₂)⋅cos(q₃ + q₄) - 1.0⋅g⋅l₁⋅m₄⋅sin(q₃)⋅sin(q₂ + q₄)⋅cos(q₁) - 1.0⋅ ↪
#
# ↪                                                                                                  ↪
# ↪ g⋅l₁⋅m₄⋅sin(q₄)⋅sin(q₁ + q₂)⋅cos(q₃) + 1.0⋅g⋅l₁⋅m₄⋅cos(q₂)⋅cos(q₄)⋅cos(q₁ + q₃) + 1.0⋅g⋅l₂⋅m₃⋅co ↪
#
# ↪                                                                                                  ↪
# ↪ s(q₁ + q₂ + q₃) - 1.0⋅g⋅l₂⋅m₄⋅sin(q₁)⋅sin(q₂)⋅cos(q₃ + q₄) - 1.0⋅g⋅l₂⋅m₄⋅sin(q₃)⋅sin(q₂ + q₄)⋅co ↪
#
# ↪                                                                                                  ↪
# ↪ s(q₁) - 1.0⋅g⋅l₂⋅m₄⋅sin(q₄)⋅sin(q₁ + q₂)⋅cos(q₃) + 1.0⋅g⋅l₂⋅m₄⋅cos(q₂)⋅cos(q₄)⋅cos(q₁ + q₃) - 1. ↪
#
# ↪                                                                                                  ↪
# ↪ 0⋅g⋅l₃⋅m₄⋅sin(q₁)⋅sin(q₂)⋅cos(q₃ + q₄) - 1.0⋅g⋅l₃⋅m₄⋅sin(q₃)⋅sin(q₂ + q₄)⋅cos(q₁) - 1.0⋅g⋅l₃⋅m₄⋅ ↪
#
# ↪                                                                                                  ↪
# ↪ sin(q₄)⋅sin(q₁ + q₂)⋅cos(q₃) + 1.0⋅g⋅l₃⋅m₄⋅cos(q₂)⋅cos(q₄)⋅cos(q₁ + q₃) + 1.0⋅g⋅lc₂⋅m₂⋅cos(q₁ +  ↪
#
# ↪                                                                                                  ↪
# ↪ q₂) + 1.0⋅g⋅lc₃⋅m₃⋅cos(q₁ + q₂ + q₃) - 1.0⋅g⋅lc₄⋅m₄⋅sin(q₁)⋅sin(q₂)⋅cos(q₃ + q₄) - 1.0⋅g⋅lc₄⋅m₄⋅ ↪
#
# ↪                                                                                                  ↪
# ↪ sin(q₃)⋅sin(q₂ + q₄)⋅cos(q₁) - 1.0⋅g⋅lc₄⋅m₄⋅sin(q₄)⋅sin(q₁ + q₂)⋅cos(q₃) + 1.0⋅g⋅lc₄⋅m₄⋅cos(q₂)⋅ ↪
#
# ↪                                              2                                 2                 ↪
# ↪ cos(q₄)⋅cos(q₁ + q₃) + 1.0⋅lc₁⋅lc₂⋅m₂⋅q_1_dot ⋅sin(q₂) + 1.0⋅lc₁⋅lc₂⋅m₃⋅q_1_dot ⋅sin(q₂) + 1.0⋅l ↪
#
# ↪                  2                                 2                                      2      ↪
# ↪ c₁⋅lc₂⋅m₄⋅q_1_dot ⋅sin(q₂) + 1.0⋅lc₁⋅lc₃⋅m₃⋅q_1_dot ⋅sin(q₂ + q₃) + 1.0⋅lc₁⋅lc₃⋅m₄⋅q_1_dot ⋅sin( ↪
#
# ↪                                  2                            2                   2              ↪
# ↪ q₂ + q₃) + 1.0⋅lc₁⋅lc₄⋅m₄⋅q_1_dot ⋅sin(q₂ + q₃ + q₄) + 1.0⋅lc₂ ⋅m₂⋅q_2_ḋ + 1.0⋅lc₂ ⋅m₃⋅q_2_ḋ + 1 ↪
#
# ↪       2                                                                                          ↪
# ↪ .0⋅lc₂ ⋅m₄⋅q_2_ḋ - 2.0⋅lc₂⋅lc₃⋅m₃⋅q_1_dot⋅q_3_dot⋅sin(q₃) + 2.0⋅lc₂⋅lc₃⋅m₃⋅q_2_ḋ⋅cos(q₃) - 2.0⋅l ↪
#
# ↪                                                           2                                      ↪
# ↪ c₂⋅lc₃⋅m₃⋅q_2_dot⋅q_3_dot⋅sin(q₃) - 1.0⋅lc₂⋅lc₃⋅m₃⋅q_3_dot ⋅sin(q₃) - 2.0⋅lc₂⋅lc₃⋅m₄⋅q_1_dot⋅q_3 ↪
#
# ↪                                                                                                  ↪
# ↪ _dot⋅sin(q₃) + 2.0⋅lc₂⋅lc₃⋅m₄⋅q_2_ḋ⋅cos(q₃) - 2.0⋅lc₂⋅lc₃⋅m₄⋅q_2_dot⋅q_3_dot⋅sin(q₃) - 1.0⋅lc₂⋅l ↪
#
# ↪              2                                                                                   ↪
# ↪ c₃⋅m₄⋅q_3_dot ⋅sin(q₃) - 2.0⋅lc₂⋅lc₄⋅m₄⋅q_1_dot⋅q_3_dot⋅sin(q₃ + q₄) - 2.0⋅lc₂⋅lc₄⋅m₄⋅q_1_dot⋅q_ ↪
#
# ↪                                                                                                  ↪
# ↪ 4_dot⋅sin(q₃ + q₄) + 2.0⋅lc₂⋅lc₄⋅m₄⋅q_2_ḋ⋅cos(q₃ + q₄) - 2.0⋅lc₂⋅lc₄⋅m₄⋅q_2_dot⋅q_3_dot⋅sin(q₃ + ↪
#
# ↪                                                                            2                     ↪
# ↪  q₄) - 2.0⋅lc₂⋅lc₄⋅m₄⋅q_2_dot⋅q_4_dot⋅sin(q₃ + q₄) - 1.0⋅lc₂⋅lc₄⋅m₄⋅q_3_dot ⋅sin(q₃ + q₄) - 2.0⋅ ↪
#
# ↪                                                                 2                       2        ↪
# ↪ lc₂⋅lc₄⋅m₄⋅q_3_dot⋅q_4_dot⋅sin(q₃ + q₄) - 1.0⋅lc₂⋅lc₄⋅m₄⋅q_4_dot ⋅sin(q₃ + q₄) + 1.0⋅lc₃ ⋅m₃⋅q_2 ↪
#
# ↪             2                                                                                    ↪
# ↪ _ḋ + 1.0⋅lc₃ ⋅m₄⋅q_2_ḋ - 2.0⋅lc₃⋅lc₄⋅m₄⋅q_1_dot⋅q_4_dot⋅sin(q₄) + 2.0⋅lc₃⋅lc₄⋅m₄⋅q_2_ḋ⋅cos(q₄) - ↪
#
# ↪                                                                                                  ↪
# ↪  2.0⋅lc₃⋅lc₄⋅m₄⋅q_2_dot⋅q_4_dot⋅sin(q₄) - 2.0⋅lc₃⋅lc₄⋅m₄⋅q_3_dot⋅q_4_dot⋅sin(q₄) - 1.0⋅lc₃⋅lc₄⋅m ↪
#
# ↪          2                  2
# ↪ ₄⋅q_4_dot ⋅sin(q₄) + 1.0⋅lc₄ ⋅m₄⋅q_2_ḋ - 1.0⋅τ₂
#
# Ecuación 3:
#                                                                                                    ↪
# 1.0⋅I₃⋅q_3_ḋ + 1.0⋅I₄⋅q_3_ḋ + 1.0⋅g⋅l₁⋅m₃⋅cos(q₁ + q₂ + q₃) - 1.0⋅g⋅l₁⋅m₄⋅sin(q₁)⋅sin(q₂)⋅cos(q₃ + ↪
#
# ↪                                                                                                  ↪
# ↪  q₄) - 1.0⋅g⋅l₁⋅m₄⋅sin(q₃)⋅sin(q₂ + q₄)⋅cos(q₁) - 1.0⋅g⋅l₁⋅m₄⋅sin(q₄)⋅sin(q₁ + q₂)⋅cos(q₃) + 1.0 ↪
#
# ↪                                                                                                  ↪
# ↪ ⋅g⋅l₁⋅m₄⋅cos(q₂)⋅cos(q₄)⋅cos(q₁ + q₃) + 1.0⋅g⋅l₂⋅m₃⋅cos(q₁ + q₂ + q₃) - 1.0⋅g⋅l₂⋅m₄⋅sin(q₁)⋅sin( ↪
#
# ↪                                                                                                  ↪
# ↪ q₂)⋅cos(q₃ + q₄) - 1.0⋅g⋅l₂⋅m₄⋅sin(q₃)⋅sin(q₂ + q₄)⋅cos(q₁) - 1.0⋅g⋅l₂⋅m₄⋅sin(q₄)⋅sin(q₁ + q₂)⋅c ↪
#
# ↪                                                                                                  ↪
# ↪ os(q₃) + 1.0⋅g⋅l₂⋅m₄⋅cos(q₂)⋅cos(q₄)⋅cos(q₁ + q₃) - 1.0⋅g⋅l₃⋅m₄⋅sin(q₁)⋅sin(q₂)⋅cos(q₃ + q₄) - 1 ↪
#
# ↪                                                                                                  ↪
# ↪ .0⋅g⋅l₃⋅m₄⋅sin(q₃)⋅sin(q₂ + q₄)⋅cos(q₁) - 1.0⋅g⋅l₃⋅m₄⋅sin(q₄)⋅sin(q₁ + q₂)⋅cos(q₃) + 1.0⋅g⋅l₃⋅m₄ ↪
#
# ↪                                                                                                  ↪
# ↪ ⋅cos(q₂)⋅cos(q₄)⋅cos(q₁ + q₃) + 1.0⋅g⋅lc₃⋅m₃⋅cos(q₁ + q₂ + q₃) - 1.0⋅g⋅lc₄⋅m₄⋅sin(q₁)⋅sin(q₂)⋅co ↪
#
# ↪                                                                                                  ↪
# ↪ s(q₃ + q₄) - 1.0⋅g⋅lc₄⋅m₄⋅sin(q₃)⋅sin(q₂ + q₄)⋅cos(q₁) - 1.0⋅g⋅lc₄⋅m₄⋅sin(q₄)⋅sin(q₁ + q₂)⋅cos(q ↪
#
# ↪                                                                        2                         ↪
# ↪ ₃) + 1.0⋅g⋅lc₄⋅m₄⋅cos(q₂)⋅cos(q₄)⋅cos(q₁ + q₃) + 1.0⋅lc₁⋅lc₃⋅m₃⋅q_1_dot ⋅sin(q₂ + q₃) + 1.0⋅lc₁⋅ ↪
#
# ↪               2                                      2                                           ↪
# ↪ lc₃⋅m₄⋅q_1_dot ⋅sin(q₂ + q₃) + 1.0⋅lc₁⋅lc₄⋅m₄⋅q_1_dot ⋅sin(q₂ + q₃ + q₄) + 1.0⋅lc₂⋅lc₃⋅m₃⋅q_1_do ↪
#
# ↪  2                                                                          2                    ↪
# ↪ t ⋅sin(q₃) + 2.0⋅lc₂⋅lc₃⋅m₃⋅q_1_dot⋅q_2_dot⋅sin(q₃) + 1.0⋅lc₂⋅lc₃⋅m₃⋅q_2_dot ⋅sin(q₃) + 1.0⋅lc₂⋅ ↪
#
# ↪               2                                                                          2       ↪
# ↪ lc₃⋅m₄⋅q_1_dot ⋅sin(q₃) + 2.0⋅lc₂⋅lc₃⋅m₄⋅q_1_dot⋅q_2_dot⋅sin(q₃) + 1.0⋅lc₂⋅lc₃⋅m₄⋅q_2_dot ⋅sin(q ↪
#
# ↪                            2                                                                     ↪
# ↪ ₃) + 1.0⋅lc₂⋅lc₄⋅m₄⋅q_1_dot ⋅sin(q₃ + q₄) + 2.0⋅lc₂⋅lc₄⋅m₄⋅q_1_dot⋅q_2_dot⋅sin(q₃ + q₄) + 1.0⋅lc ↪
#
# ↪                 2                       2                   2                                    ↪
# ↪ ₂⋅lc₄⋅m₄⋅q_2_dot ⋅sin(q₃ + q₄) + 1.0⋅lc₃ ⋅m₃⋅q_3_ḋ + 1.0⋅lc₃ ⋅m₄⋅q_3_ḋ - 2.0⋅lc₃⋅lc₄⋅m₄⋅q_1_dot⋅ ↪
#
# ↪                                                                                                  ↪
# ↪ q_4_dot⋅sin(q₄) - 2.0⋅lc₃⋅lc₄⋅m₄⋅q_2_dot⋅q_4_dot⋅sin(q₄) + 2.0⋅lc₃⋅lc₄⋅m₄⋅q_3_ḋ⋅cos(q₄) - 2.0⋅lc ↪
#
# ↪                                                          2                  2
# ↪ ₃⋅lc₄⋅m₄⋅q_3_dot⋅q_4_dot⋅sin(q₄) - 1.0⋅lc₃⋅lc₄⋅m₄⋅q_4_dot ⋅sin(q₄) + 1.0⋅lc₄ ⋅m₄⋅q_3_ḋ - 1.0⋅τ₃
#
# Ecuación 4:
#                                                                                                    ↪
# 1.0⋅I₄⋅q_4_ḋ + 1.0⋅g⋅l₁⋅m₄⋅cos(q₁ + q₂ + q₃ + q₄) + 1.0⋅g⋅l₂⋅m₄⋅cos(q₁ + q₂ + q₃ + q₄) + 1.0⋅g⋅l₃⋅ ↪
#
# ↪                                                                                         2        ↪
# ↪ m₄⋅cos(q₁ + q₂ + q₃ + q₄) + 1.0⋅g⋅lc₄⋅m₄⋅cos(q₁ + q₂ + q₃ + q₄) - 1.0⋅lc₁⋅lc₄⋅m₄⋅q_1_dot ⋅sin(q₁ ↪
#
# ↪                                                  2                                               ↪
# ↪ )⋅cos(q₁ + q₂ + q₃ + q₄) + 1.0⋅lc₁⋅lc₄⋅m₄⋅q_1_dot ⋅sin(q₁ + q₂ + q₃ + q₄)⋅cos(q₁) - 1.0⋅lc₂⋅lc₄⋅ ↪
#
# ↪           2                                                             2                        ↪
# ↪ m₄⋅q_1_dot ⋅sin(q₁ + q₂)⋅cos(q₁ + q₂ + q₃ + q₄) + 1.0⋅lc₂⋅lc₄⋅m₄⋅q_1_dot ⋅sin(q₁ + q₂ + q₃ + q₄) ↪
#
# ↪                                                                                                  ↪
# ↪ ⋅cos(q₁ + q₂) - 2.0⋅lc₂⋅lc₄⋅m₄⋅q_1_dot⋅q_2_dot⋅sin(q₁ + q₂)⋅cos(q₁ + q₂ + q₃ + q₄) + 2.0⋅lc₂⋅lc₄ ↪
#
# ↪                                                                                 2                ↪
# ↪ ⋅m₄⋅q_1_dot⋅q_2_dot⋅sin(q₁ + q₂ + q₃ + q₄)⋅cos(q₁ + q₂) - 1.0⋅lc₂⋅lc₄⋅m₄⋅q_2_dot ⋅sin(q₁ + q₂)⋅c ↪
#
# ↪                                               2                                                  ↪
# ↪ os(q₁ + q₂ + q₃ + q₄) + 1.0⋅lc₂⋅lc₄⋅m₄⋅q_2_dot ⋅sin(q₁ + q₂ + q₃ + q₄)⋅cos(q₁ + q₂) - 1.0⋅lc₃⋅lc ↪
#
# ↪             2                                                                  2                 ↪
# ↪ ₄⋅m₄⋅q_1_dot ⋅sin(q₁ + q₂ + q₃)⋅cos(q₁ + q₂ + q₃ + q₄) + 1.0⋅lc₃⋅lc₄⋅m₄⋅q_1_dot ⋅sin(q₁ + q₂ + q ↪
#
# ↪                                                                                                  ↪
# ↪ ₃ + q₄)⋅cos(q₁ + q₂ + q₃) - 2.0⋅lc₃⋅lc₄⋅m₄⋅q_1_dot⋅q_2_dot⋅sin(q₁ + q₂ + q₃)⋅cos(q₁ + q₂ + q₃ +  ↪
#
# ↪                                                                                                  ↪
# ↪ q₄) + 2.0⋅lc₃⋅lc₄⋅m₄⋅q_1_dot⋅q_2_dot⋅sin(q₁ + q₂ + q₃ + q₄)⋅cos(q₁ + q₂ + q₃) - 2.0⋅lc₃⋅lc₄⋅m₄⋅q ↪
#
# ↪                                                                                                  ↪
# ↪ _1_dot⋅q_3_dot⋅sin(q₁ + q₂ + q₃)⋅cos(q₁ + q₂ + q₃ + q₄) + 2.0⋅lc₃⋅lc₄⋅m₄⋅q_1_dot⋅q_3_dot⋅sin(q₁  ↪
#
# ↪                                                           2                                      ↪
# ↪ + q₂ + q₃ + q₄)⋅cos(q₁ + q₂ + q₃) - 1.0⋅lc₃⋅lc₄⋅m₄⋅q_2_dot ⋅sin(q₁ + q₂ + q₃)⋅cos(q₁ + q₂ + q₃ + ↪
#
# ↪                              2                                                                   ↪
# ↪  q₄) + 1.0⋅lc₃⋅lc₄⋅m₄⋅q_2_dot ⋅sin(q₁ + q₂ + q₃ + q₄)⋅cos(q₁ + q₂ + q₃) - 2.0⋅lc₃⋅lc₄⋅m₄⋅q_2_dot ↪
#
# ↪                                                                                                  ↪
# ↪ ⋅q_3_dot⋅sin(q₁ + q₂ + q₃)⋅cos(q₁ + q₂ + q₃ + q₄) + 2.0⋅lc₃⋅lc₄⋅m₄⋅q_2_dot⋅q_3_dot⋅sin(q₁ + q₂ + ↪
#
# ↪                                                     2                                            ↪
# ↪  q₃ + q₄)⋅cos(q₁ + q₂ + q₃) - 1.0⋅lc₃⋅lc₄⋅m₄⋅q_3_dot ⋅sin(q₁ + q₂ + q₃)⋅cos(q₁ + q₂ + q₃ + q₄) + ↪
#
# ↪                        2                                                   2             2       ↪
# ↪  1.0⋅lc₃⋅lc₄⋅m₄⋅q_3_dot ⋅sin(q₁ + q₂ + q₃ + q₄)⋅cos(q₁ + q₂ + q₃) + 1.0⋅lc₄ ⋅m₄⋅q_4_ḋ⋅sin (q₁ +  ↪
#
# ↪                        2             2
# ↪ q₂ + q₃ + q₄) + 1.0⋅lc₄ ⋅m₄⋅q_4_ḋ⋅cos (q₁ + q₂ + q₃ + q₄) - 1.0⋅τ₄
